# %% [markdown]
# # 1. Import Libraries and Load Data

# %% [markdown]
# ## A. Library

# %%
# Import package
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime as dt

# %% [markdown]
# ## B. Load the data

# %%
# Path of the file with escaped backslashes and load the data
file_path1 = r"C:\python-project\Perqara\data\customers_dataset.csv"
file_path2 = r"C:\python-project\Perqara\data\geolocation_dataset.csv"
file_path3 = r"C:\python-project\Perqara\data\order_items_dataset.csv"
file_path4 = r"C:\python-project\Perqara\data\order_payments_dataset.csv"
file_path5 = r"C:\python-project\Perqara\data\order_reviews_dataset.csv"
file_path6 = r"C:\python-project\Perqara\data\orders_dataset.csv"
file_path7 = r"C:\python-project\Perqara\data\product_category_name_translation.csv"
file_path8 = r"C:\python-project\Perqara\data\products_dataset.csv"
file_path9 = r"C:\python-project\Perqara\data\sellers_dataset.csv"

# Read the CSV file into a pandas DataFrame
customers = pd.read_csv(file_path1)
geolocation = pd.read_csv(file_path2)
order_items = pd.read_csv(file_path3)
order_payments = pd.read_csv(file_path4)
order_reviews = pd.read_csv(file_path5)
orders = pd.read_csv(file_path6)
product_category = pd.read_csv(file_path7)
products = pd.read_csv(file_path8)
sellers = pd.read_csv(file_path9)

# %%
# Display the DataFrame [1]
customers
# Out:
#                             customer_id                customer_unique_id  \
# 0      06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1      18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2      4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3      b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4      4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
# ...                                 ...                               ...
# 99436  17ddf5dd5d51696bb3d7c6291687be6f  1a29b476fee25c95fbafc67c5ac95cf8
# 99437  e7b71a9017aa05c9a7fd292d714858e8  d52a67c98be1cf6a5c84435bd38d095d
# 99438  5e28dfe12db7fb50a4b2f691faecea5e  e9f50caf99f032f0bf3c55141f019d99
# 99439  56b18e2166679b8a959d72dd06da27f9  73c2643a0a458b49f58cea58833b192e
# 99440  274fa6071e5e17fe303b9748641082c8  84732c5050c01db9b23e19ba39899398
#
#        customer_zip_code_prefix          customer_city customer_state
# 0                         14409                 franca             SP
# 1                          9790  sao bernardo do campo             SP
# 2                          1151              sao paulo             SP
# 3                          8775        mogi das cruzes             SP
# 4                         13056               campinas             SP
# ...                         ...                    ...            ...
# 99436                      3937              sao paulo             SP
# 99437                      6764        taboao da serra             SP
# 99438                     60115              fortaleza             CE
# 99439                     92120                 canoas             RS
# 99440                      6703                  cotia             SP
#
# [99441 rows x 5 columns]

# %%
# [2]
geolocation
# Out:
#          geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                               1037       -23.545621       -46.639292
# 1                               1046       -23.546081       -46.644820
# 2                               1046       -23.546129       -46.642951
# 3                               1041       -23.544392       -46.639499
# 4                               1035       -23.541578       -46.641607
# ...                              ...              ...              ...
# 1000158                        99950       -28.068639       -52.010705
# 1000159                        99900       -27.877125       -52.224882
# 1000160                        99950       -28.071855       -52.014716
# 1000161                        99980       -28.388932       -51.846871
# 1000162                        99950       -28.070104       -52.018658
#
#         geolocation_city geolocation_state
# 0              sao paulo                SP
# 1              sao paulo                SP
# 2              sao paulo                SP
# 3              sao paulo                SP
# 4              sao paulo                SP
# ...                  ...               ...
# 1000158         tapejara                RS
# 1000159   getulio vargas                RS
# 1000160         tapejara                RS
# 1000161  david canabarro                RS
# 1000162         tapejara                RS
#
# [1000163 rows x 5 columns]

# %%
# [3]
order_items
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2       c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3       7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4       ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
# ...                                  ...                               ...
# 112645  4aa6014eceb682077f9dc4bffebc05b0  b8bc237ba3788b23da09c0f1f3a3288c
# 112646  32e07fd915822b0765e448c4dd74c828  f3c38ab652836d21de61fb8314b69182
# 112647  72a30483855e2eafc67aee5dc2560482  c3cfdc648177fdbbbb35635a37472c53
# 112648  9c422a519119dcad7575db5af1ba540e  2b3e4a2a3ea8e01938cabda2a3e5cc79
# 112649  350688d9dc1e75ff97be326363655e01  f7ccf836d21b2fb1de37564105216cc1
#
#         shipping_limit_date   price  freight_value
# 0       2017-09-19 09:45:35   58.90          13.29
# 1       2017-05-03 11:05:13  239.90          19.93
# 2       2018-01-18 14:48:30  199.00          17.87
# 3       2018-08-15 10:10:18   12.99          12.79
# 4       2017-02-13 13:57:51  199.90          18.14
# ...                     ...     ...            ...
# 112645  2018-05-02 04:11:01  299.99          43.41
# 112646  2018-07-20 04:31:48  350.00          36.53
# 112647  2017-10-30 17:14:25   99.90          16.95
# 112648  2017-08-21 00:04:32   55.99           8.72
# 112649  2018-06-12 17:10:13   43.00          12.79
#
# [112650 rows x 7 columns]

# %%
# [4]
order_payments
# Out:
#                                 order_id  payment_sequential payment_type  \
# 0       b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1       a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2       25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3       ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4       42fdf880ba16b47b59251dd489d4441a                   1  credit_card
# ...                                  ...                 ...          ...
# 103881  0406037ad97740d563a178ecc7a2075c                   1       boleto
# 103882  7b905861d7c825891d6347454ea7863f                   1  credit_card
# 103883  32609bbb3dd69b3c066a6860554a77bf                   1  credit_card
# 103884  b8b61059626efa996a60be9bb9320e10                   1  credit_card
# 103885  28bbae6599b09d39ca406b747b6632b1                   1       boleto
#
#         payment_installments  payment_value
# 0                          8          99.33
# 1                          1          24.39
# 2                          1          65.71
# 3                          8         107.78
# 4                          2         128.45
# ...                      ...            ...
# 103881                     1         363.31
# 103882                     2          96.80
# 103883                     1          47.77
# 103884                     5         369.54
# 103885                     1         191.58
#
# [103886 rows x 5 columns]

# %%
# [5]
order_reviews
# Out:
#                               review_id                          order_id  \
# 0      7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1      80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2      228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3      e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4      f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
# ...                                 ...                               ...
# 99219  574ed12dd733e5fa530cfd4bbf39d7c9  2a8c23fee101d4d5662fa670396eb8da
# 99220  f3897127253a9592a73be9bdfdf4ed7a  22ec9f0669f784db00fa86d035cf8602
# 99221  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 99222  1adeb9d84d72fe4e337617733eb85149  7725825d039fc1f0ceb7635e3f7d9206
# 99223  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#        review_score review_comment_title  \
# 0                 4                  NaN
# 1                 5                  NaN
# 2                 5                  NaN
# 3                 5                  NaN
# 4                 5                  NaN
# ...             ...                  ...
# 99219             5                  NaN
# 99220             5                  NaN
# 99221             5                  NaN
# 99222             4                  NaN
# 99223             1                  NaN
#
#                                   review_comment_message review_creation_date  \
# 0                                                    NaN  2018-01-18 00:00:00
# 1                                                    NaN  2018-03-10 00:00:00
# 2                                                    NaN  2018-02-17 00:00:00
# 3                  Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4      Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
# ...                                                  ...                  ...
# 99219                                                NaN  2018-07-07 00:00:00
# 99220                                                NaN  2017-12-09 00:00:00
# 99221  Excelente mochila, entrega super rápida. Super...  2018-03-22 00:00:00
# 99222                                                NaN  2018-07-01 00:00:00
# 99223  meu produto chegou e ja tenho que devolver, po...  2017-07-03 00:00:00
#
#       review_answer_timestamp
# 0         2018-01-18 21:46:59
# 1         2018-03-11 03:05:13
# 2         2018-02-18 14:36:24
# 3         2017-04-21 22:02:06
# 4         2018-03-02 10:26:53
# ...                       ...
# 99219     2018-07-14 17:18:30
# 99220     2017-12-11 20:06:42
# 99221     2018-03-23 09:10:43
# 99222     2018-07-02 12:59:13
# 99223     2017-07-03 21:01:49
#
# [99224 rows x 7 columns]

# %%
# [6]
orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# 0        delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1        delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2        delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3        delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4        delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
# ...            ...                      ...                  ...
# 99436    delivered      2017-03-09 09:54:05  2017-03-09 09:54:05
# 99437    delivered      2018-02-06 12:58:58  2018-02-06 13:10:37
# 99438    delivered      2017-08-27 14:46:43  2017-08-27 15:04:16
# 99439    delivered      2018-01-08 21:28:27  2018-01-08 21:36:21
# 99440    delivered      2018-03-08 20:57:30  2018-03-09 11:20:28
#
#       order_delivered_carrier_date order_delivered_customer_date  \
# 0              2017-10-04 19:55:00           2017-10-10 21:25:13
# 1              2018-07-26 14:31:00           2018-08-07 15:27:45
# 2              2018-08-08 13:50:00           2018-08-17 18:06:29
# 3              2017-11-22 13:39:59           2017-12-02 00:28:42
# 4              2018-02-14 19:46:34           2018-02-16 18:17:02
# ...                            ...                           ...
# 99436          2017-03-10 11:18:03           2017-03-17 15:08:01
# 99437          2018-02-07 23:22:42           2018-02-28 17:37:56
# 99438          2017-08-28 20:52:26           2017-09-21 11:24:17
# 99439          2018-01-12 15:35:03           2018-01-25 23:32:54
# 99440          2018-03-09 22:11:59           2018-03-16 13:08:30
#
#       order_estimated_delivery_date
# 0               2017-10-18 00:00:00
# 1               2018-08-13 00:00:00
# 2               2018-09-04 00:00:00
# 3               2017-12-15 00:00:00
# 4               2018-02-26 00:00:00
# ...                             ...
# 99436           2017-03-28 00:00:00
# 99437           2018-03-02 00:00:00
# 99438           2017-09-27 00:00:00
# 99439           2018-02-15 00:00:00
# 99440           2018-04-03 00:00:00
#
# [99441 rows x 8 columns]

# %%
# [7]
product_category
# Out:
#             product_category_name product_category_name_english
# 0                    beleza_saude                 health_beauty
# 1          informatica_acessorios         computers_accessories
# 2                      automotivo                          auto
# 3                 cama_mesa_banho                bed_bath_table
# 4                moveis_decoracao               furniture_decor
# ..                            ...                           ...
# 66                         flores                       flowers
# 67             artes_e_artesanato         arts_and_craftmanship
# 68                fraldas_higiene           diapers_and_hygiene
# 69  fashion_roupa_infanto_juvenil     fashion_childrens_clothes
# 70             seguros_e_servicos         security_and_services
#
# [71 rows x 2 columns]

# %%
# [8]
products
# Out:
#                              product_id              product_category_name  \
# 0      1e9e8ef04dbcff4541ed26657ea517e5                         perfumaria
# 1      3aa071139cb16b67ca9e5dea641aaa2f                              artes
# 2      96bd76ec8810374ed1b65e291975717f                      esporte_lazer
# 3      cef67bcfe19066a932b7673e239eb23d                              bebes
# 4      9dc1a7de274444849c219cff195d0b71              utilidades_domesticas
# ...                                 ...                                ...
# 32946  a0b7d5a992ccda646f2d34e418fff5a0                   moveis_decoracao
# 32947  bf4538d88321d0fd4412a93c974510e6  construcao_ferramentas_iluminacao
# 32948  9a7c6041fa9592d9d9ef6cfe62a71f8c                    cama_mesa_banho
# 32949  83808703fc0706a22e264b9d75f04a2e             informatica_acessorios
# 32950  106392145fca363410d287a815be6de4                    cama_mesa_banho
#
#        product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                     40.0                       287.0                 1.0
# 1                     44.0                       276.0                 1.0
# 2                     46.0                       250.0                 1.0
# 3                     27.0                       261.0                 1.0
# 4                     37.0                       402.0                 4.0
# ...                    ...                         ...                 ...
# 32946                 45.0                        67.0                 2.0
# 32947                 41.0                       971.0                 1.0
# 32948                 50.0                       799.0                 1.0
# 32949                 60.0                       156.0                 2.0
# 32950                 58.0                       309.0                 1.0
#
#        product_weight_g  product_length_cm  product_height_cm  \
# 0                 225.0               16.0               10.0
# 1                1000.0               30.0               18.0
# 2                 154.0               18.0                9.0
# 3                 371.0               26.0                4.0
# 4                 625.0               20.0               17.0
# ...                 ...                ...                ...
# 32946           12300.0               40.0               40.0
# 32947            1700.0               16.0               19.0
# 32948            1400.0               27.0                7.0
# 32949             700.0               31.0               13.0
# 32950            2083.0               12.0                2.0
#
#        product_width_cm
# 0                  14.0
# 1                  20.0
# 2                  15.0
# 3                  26.0
# 4                  13.0
# ...                 ...
# 32946              40.0
# 32947              16.0
# 32948              27.0
# 32949              20.0
# 32950               7.0
#
# [32951 rows x 9 columns]

# %%
# [9]
sellers
# Out:
#                              seller_id  seller_zip_code_prefix  \
# 0     3442f8959a84dea7ee197c632cb2df15                   13023
# 1     d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2     ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3     c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4     51a04a8a6bdcb23deccc82b0b80742cf                   12914
# ...                                ...                     ...
# 3090  98dddbc4601dd4443ca174359b237166                   87111
# 3091  f8201cab383e484733266d1906e2fdfa                   88137
# 3092  74871d19219c7d518d0090283e03c137                    4650
# 3093  e603cf3fec55f8697c9059638d6c8eb5                   96080
# 3094  9e25199f6ef7e7c347120ff175652c3b                   12051
#
#             seller_city seller_state
# 0              campinas           SP
# 1            mogi guacu           SP
# 2        rio de janeiro           RJ
# 3             sao paulo           SP
# 4     braganca paulista           SP
# ...                 ...          ...
# 3090            sarandi           PR
# 3091            palhoca           SC
# 3092          sao paulo           SP
# 3093            pelotas           RS
# 3094            taubate           SP
#
# [3095 rows x 4 columns]

# %% [markdown]
# ## C. Merge data from different table

# %%
# [1]
def add_order_info1(data, orders):
    """
    Adds customer_id and order_status columns to 'data' based on order_id

    Args:
        data: DataFrame containing order items data
        orders: DataFrame containing order data

    Returns:
        DataFrame: Enriched order_items DataFrame
    """
    data = data.merge(orders[['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp']], on='order_id', how='left')
    return data

data = order_items
data = add_order_info1(data, orders)
data
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2       c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3       7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4       ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
# ...                                  ...                               ...
# 112645  4aa6014eceb682077f9dc4bffebc05b0  b8bc237ba3788b23da09c0f1f3a3288c
# 112646  32e07fd915822b0765e448c4dd74c828  f3c38ab652836d21de61fb8314b69182
# 112647  72a30483855e2eafc67aee5dc2560482  c3cfdc648177fdbbbb35635a37472c53
# 112648  9c422a519119dcad7575db5af1ba540e  2b3e4a2a3ea8e01938cabda2a3e5cc79
# 112649  350688d9dc1e75ff97be326363655e01  f7ccf836d21b2fb1de37564105216cc1
#
#         shipping_limit_date   price  freight_value  \
# 0       2017-09-19 09:45:35   58.90          13.29
# 1       2017-05-03 11:05:13  239.90          19.93
# 2       2018-01-18 14:48:30  199.00          17.87
# 3       2018-08-15 10:10:18   12.99          12.79
# 4       2017-02-13 13:57:51  199.90          18.14
# ...                     ...     ...            ...
# 112645  2018-05-02 04:11:01  299.99          43.41
# 112646  2018-07-20 04:31:48  350.00          36.53
# 112647  2017-10-30 17:14:25   99.90          16.95
# 112648  2017-08-21 00:04:32   55.99           8.72
# 112649  2018-06-12 17:10:13   43.00          12.79
#
#                              customer_id order_status order_purchase_timestamp
# 0       3ce436f183e68e07877b285a838db11a    delivered      2017-09-13 08:59:02
# 1       f6dd3ec061db4e3987629fe6b26e5cce    delivered      2017-04-26 10:53:06
# 2       6489ae5e4333f3693df5ad4372dab6d3    delivered      2018-01-14 14:33:31
# 3       d4eb9395c8c0431ee92fce09860c5a06    delivered      2018-08-08 10:00:35
# 4       58dbd0b2d70206bf40e62cd34e84d795    delivered      2017-02-04 13:57:51
# ...                                  ...          ...                      ...
# 112645  b51593916b4b8e0d6f66f2ae24f2673d    delivered      2018-04-23 13:57:06
# 112646  84c5d4fbaf120aae381fad077416eaa0    delivered      2018-07-14 10:26:46
# 112647  29309aa813182aaddc9b259e31b870e6    delivered      2017-10-23 17:07:56
# 112648  b5e6afd5a41800fdf401e0272ca74655    delivered      2017-08-14 23:02:59
# 112649  96d649da0cc4ff33bb408b199d4c7dcf    delivered      2018-06-09 17:00:18
#
# [112650 rows x 10 columns]

# %%
# [2] Adds product_category_name columns to 'data' based on product_id
def add_order_info2(data, products):
    data = data.merge(products[['product_id', 'product_category_name']], on='product_id', how='left')
    return data

data = add_order_info2(data, products)
data
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2       c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3       7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4       ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
# ...                                  ...                               ...
# 112645  4aa6014eceb682077f9dc4bffebc05b0  b8bc237ba3788b23da09c0f1f3a3288c
# 112646  32e07fd915822b0765e448c4dd74c828  f3c38ab652836d21de61fb8314b69182
# 112647  72a30483855e2eafc67aee5dc2560482  c3cfdc648177fdbbbb35635a37472c53
# 112648  9c422a519119dcad7575db5af1ba540e  2b3e4a2a3ea8e01938cabda2a3e5cc79
# 112649  350688d9dc1e75ff97be326363655e01  f7ccf836d21b2fb1de37564105216cc1
#
#         shipping_limit_date   price  freight_value  \
# 0       2017-09-19 09:45:35   58.90          13.29
# 1       2017-05-03 11:05:13  239.90          19.93
# 2       2018-01-18 14:48:30  199.00          17.87
# 3       2018-08-15 10:10:18   12.99          12.79
# 4       2017-02-13 13:57:51  199.90          18.14
# ...                     ...     ...            ...
# 112645  2018-05-02 04:11:01  299.99          43.41
# 112646  2018-07-20 04:31:48  350.00          36.53
# 112647  2017-10-30 17:14:25   99.90          16.95
# 112648  2017-08-21 00:04:32   55.99           8.72
# 112649  2018-06-12 17:10:13   43.00          12.79
#
#                              customer_id order_status  \
# 0       3ce436f183e68e07877b285a838db11a    delivered
# 1       f6dd3ec061db4e3987629fe6b26e5cce    delivered
# 2       6489ae5e4333f3693df5ad4372dab6d3    delivered
# 3       d4eb9395c8c0431ee92fce09860c5a06    delivered
# 4       58dbd0b2d70206bf40e62cd34e84d795    delivered
# ...                                  ...          ...
# 112645  b51593916b4b8e0d6f66f2ae24f2673d    delivered
# 112646  84c5d4fbaf120aae381fad077416eaa0    delivered
# 112647  29309aa813182aaddc9b259e31b870e6    delivered
# 112648  b5e6afd5a41800fdf401e0272ca74655    delivered
# 112649  96d649da0cc4ff33bb408b199d4c7dcf    delivered
#
#        order_purchase_timestamp   product_category_name
# 0           2017-09-13 08:59:02              cool_stuff
# 1           2017-04-26 10:53:06                pet_shop
# 2           2018-01-14 14:33:31        moveis_decoracao
# 3           2018-08-08 10:00:35              perfumaria
# 4           2017-02-04 13:57:51      ferramentas_jardim
# ...                         ...                     ...
# 112645      2018-04-23 13:57:06   utilidades_domesticas
# 112646      2018-07-14 10:26:46  informatica_acessorios
# 112647      2017-10-23 17:07:56           esporte_lazer
# 112648      2017-08-14 23:02:59  informatica_acessorios
# 112649      2018-06-09 17:00:18         cama_mesa_banho
#
# [112650 rows x 11 columns]

# %%
# [3] Adds product_category_name_english columns to 'data' based on product_category_name
def add_order_info3(data, product_category):
    data = data.merge(product_category[['product_category_name', 'product_category_name_english']], on='product_category_name', how='left')
    return data

data = add_order_info3(data, product_category)
data
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2       c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3       7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4       ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
# ...                                  ...                               ...
# 112645  4aa6014eceb682077f9dc4bffebc05b0  b8bc237ba3788b23da09c0f1f3a3288c
# 112646  32e07fd915822b0765e448c4dd74c828  f3c38ab652836d21de61fb8314b69182
# 112647  72a30483855e2eafc67aee5dc2560482  c3cfdc648177fdbbbb35635a37472c53
# 112648  9c422a519119dcad7575db5af1ba540e  2b3e4a2a3ea8e01938cabda2a3e5cc79
# 112649  350688d9dc1e75ff97be326363655e01  f7ccf836d21b2fb1de37564105216cc1
#
#         shipping_limit_date   price  freight_value  \
# 0       2017-09-19 09:45:35   58.90          13.29
# 1       2017-05-03 11:05:13  239.90          19.93
# 2       2018-01-18 14:48:30  199.00          17.87
# 3       2018-08-15 10:10:18   12.99          12.79
# 4       2017-02-13 13:57:51  199.90          18.14
# ...                     ...     ...            ...
# 112645  2018-05-02 04:11:01  299.99          43.41
# 112646  2018-07-20 04:31:48  350.00          36.53
# 112647  2017-10-30 17:14:25   99.90          16.95
# 112648  2017-08-21 00:04:32   55.99           8.72
# 112649  2018-06-12 17:10:13   43.00          12.79
#
#                              customer_id order_status  \
# 0       3ce436f183e68e07877b285a838db11a    delivered
# 1       f6dd3ec061db4e3987629fe6b26e5cce    delivered
# 2       6489ae5e4333f3693df5ad4372dab6d3    delivered
# 3       d4eb9395c8c0431ee92fce09860c5a06    delivered
# 4       58dbd0b2d70206bf40e62cd34e84d795    delivered
# ...                                  ...          ...
# 112645  b51593916b4b8e0d6f66f2ae24f2673d    delivered
# 112646  84c5d4fbaf120aae381fad077416eaa0    delivered
# 112647  29309aa813182aaddc9b259e31b870e6    delivered
# 112648  b5e6afd5a41800fdf401e0272ca74655    delivered
# 112649  96d649da0cc4ff33bb408b199d4c7dcf    delivered
#
#        order_purchase_timestamp   product_category_name  \
# 0           2017-09-13 08:59:02              cool_stuff
# 1           2017-04-26 10:53:06                pet_shop
# 2           2018-01-14 14:33:31        moveis_decoracao
# 3           2018-08-08 10:00:35              perfumaria
# 4           2017-02-04 13:57:51      ferramentas_jardim
# ...                         ...                     ...
# 112645      2018-04-23 13:57:06   utilidades_domesticas
# 112646      2018-07-14 10:26:46  informatica_acessorios
# 112647      2017-10-23 17:07:56           esporte_lazer
# 112648      2017-08-14 23:02:59  informatica_acessorios
# 112649      2018-06-09 17:00:18         cama_mesa_banho
#
#        product_category_name_english
# 0                         cool_stuff
# 1                           pet_shop
# 2                    furniture_decor
# 3                          perfumery
# 4                       garden_tools
# ...                              ...
# 112645                    housewares
# 112646         computers_accessories
# 112647                sports_leisure
# 112648         computers_accessories
# 112649                bed_bath_table
#
# [112650 rows x 12 columns]

# %%
# [4] Adds payment_value, payment_type, and payment_installments columns to 'data' based on order_id
def add_order_info4(data, order_payments):
    data = data.merge(order_payments[['order_id', 'payment_value', 'payment_type', 'payment_installments']], on='order_id', how='left')
    return data

data = add_order_info4(data, order_payments)
data
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 117599  fffc94f6ce00a00581880bf54a75a037              1
# 117600  fffcd46ef2263f404302a634eb57f7eb              1
# 117601  fffce4705a9662cd70adb13d4a31832d              1
# 117602  fffe18544ffabc95dfada21779c9644f              1
# 117603  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2       c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3       7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4       ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
# ...                                  ...                               ...
# 117599  4aa6014eceb682077f9dc4bffebc05b0  b8bc237ba3788b23da09c0f1f3a3288c
# 117600  32e07fd915822b0765e448c4dd74c828  f3c38ab652836d21de61fb8314b69182
# 117601  72a30483855e2eafc67aee5dc2560482  c3cfdc648177fdbbbb35635a37472c53
# 117602  9c422a519119dcad7575db5af1ba540e  2b3e4a2a3ea8e01938cabda2a3e5cc79
# 117603  350688d9dc1e75ff97be326363655e01  f7ccf836d21b2fb1de37564105216cc1
#
#         shipping_limit_date   price  freight_value  \
# 0       2017-09-19 09:45:35   58.90          13.29
# 1       2017-05-03 11:05:13  239.90          19.93
# 2       2018-01-18 14:48:30  199.00          17.87
# 3       2018-08-15 10:10:18   12.99          12.79
# 4       2017-02-13 13:57:51  199.90          18.14
# ...                     ...     ...            ...
# 117599  2018-05-02 04:11:01  299.99          43.41
# 117600  2018-07-20 04:31:48  350.00          36.53
# 117601  2017-10-30 17:14:25   99.90          16.95
# 117602  2017-08-21 00:04:32   55.99           8.72
# 117603  2018-06-12 17:10:13   43.00          12.79
#
#                              customer_id order_status  \
# 0       3ce436f183e68e07877b285a838db11a    delivered
# 1       f6dd3ec061db4e3987629fe6b26e5cce    delivered
# 2       6489ae5e4333f3693df5ad4372dab6d3    delivered
# 3       d4eb9395c8c0431ee92fce09860c5a06    delivered
# 4       58dbd0b2d70206bf40e62cd34e84d795    delivered
# ...                                  ...          ...
# 117599  b51593916b4b8e0d6f66f2ae24f2673d    delivered
# 117600  84c5d4fbaf120aae381fad077416eaa0    delivered
# 117601  29309aa813182aaddc9b259e31b870e6    delivered
# 117602  b5e6afd5a41800fdf401e0272ca74655    delivered
# 117603  96d649da0cc4ff33bb408b199d4c7dcf    delivered
#
#        order_purchase_timestamp   product_category_name  \
# 0           2017-09-13 08:59:02              cool_stuff
# 1           2017-04-26 10:53:06                pet_shop
# 2           2018-01-14 14:33:31        moveis_decoracao
# 3           2018-08-08 10:00:35              perfumaria
# 4           2017-02-04 13:57:51      ferramentas_jardim
# ...                         ...                     ...
# 117599      2018-04-23 13:57:06   utilidades_domesticas
# 117600      2018-07-14 10:26:46  informatica_acessorios
# 117601      2017-10-23 17:07:56           esporte_lazer
# 117602      2017-08-14 23:02:59  informatica_acessorios
# 117603      2018-06-09 17:00:18         cama_mesa_banho
#
#        product_category_name_english  payment_value payment_type  \
# 0                         cool_stuff          72.19  credit_card
# 1                           pet_shop         259.83  credit_card
# 2                    furniture_decor         216.87  credit_card
# 3                          perfumery          25.78  credit_card
# 4                       garden_tools         218.04  credit_card
# ...                              ...            ...          ...
# 117599                    housewares         343.40       boleto
# 117600         computers_accessories         386.53       boleto
# 117601                sports_leisure         116.85  credit_card
# 117602         computers_accessories          64.71  credit_card
# 117603                bed_bath_table          55.79  credit_card
#
#         payment_installments
# 0                        2.0
# 1                        3.0
# 2                        5.0
# 3                        2.0
# 4                        3.0
# ...                      ...
# 117599                   1.0
# 117600                   1.0
# 117601                   3.0
# 117602                   3.0
# 117603                   1.0
#
# [117604 rows x 15 columns]

# %%
# [5] Adds customer_unique_id columns to 'data' based on customer_id
def add_order_info5(data, customers):
    data = data.merge(customers[['customer_id', 'customer_unique_id', 'customer_city', 'customer_state']], on='customer_id', how='left')
    return data

data = add_order_info5(data, customers)
data
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 117599  fffc94f6ce00a00581880bf54a75a037              1
# 117600  fffcd46ef2263f404302a634eb57f7eb              1
# 117601  fffce4705a9662cd70adb13d4a31832d              1
# 117602  fffe18544ffabc95dfada21779c9644f              1
# 117603  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2       c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3       7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4       ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
# ...                                  ...                               ...
# 117599  4aa6014eceb682077f9dc4bffebc05b0  b8bc237ba3788b23da09c0f1f3a3288c
# 117600  32e07fd915822b0765e448c4dd74c828  f3c38ab652836d21de61fb8314b69182
# 117601  72a30483855e2eafc67aee5dc2560482  c3cfdc648177fdbbbb35635a37472c53
# 117602  9c422a519119dcad7575db5af1ba540e  2b3e4a2a3ea8e01938cabda2a3e5cc79
# 117603  350688d9dc1e75ff97be326363655e01  f7ccf836d21b2fb1de37564105216cc1
#
#         shipping_limit_date   price  freight_value  \
# 0       2017-09-19 09:45:35   58.90          13.29
# 1       2017-05-03 11:05:13  239.90          19.93
# 2       2018-01-18 14:48:30  199.00          17.87
# 3       2018-08-15 10:10:18   12.99          12.79
# 4       2017-02-13 13:57:51  199.90          18.14
# ...                     ...     ...            ...
# 117599  2018-05-02 04:11:01  299.99          43.41
# 117600  2018-07-20 04:31:48  350.00          36.53
# 117601  2017-10-30 17:14:25   99.90          16.95
# 117602  2017-08-21 00:04:32   55.99           8.72
# 117603  2018-06-12 17:10:13   43.00          12.79
#
#                              customer_id order_status  \
# 0       3ce436f183e68e07877b285a838db11a    delivered
# 1       f6dd3ec061db4e3987629fe6b26e5cce    delivered
# 2       6489ae5e4333f3693df5ad4372dab6d3    delivered
# 3       d4eb9395c8c0431ee92fce09860c5a06    delivered
# 4       58dbd0b2d70206bf40e62cd34e84d795    delivered
# ...                                  ...          ...
# 117599  b51593916b4b8e0d6f66f2ae24f2673d    delivered
# 117600  84c5d4fbaf120aae381fad077416eaa0    delivered
# 117601  29309aa813182aaddc9b259e31b870e6    delivered
# 117602  b5e6afd5a41800fdf401e0272ca74655    delivered
# 117603  96d649da0cc4ff33bb408b199d4c7dcf    delivered
#
#        order_purchase_timestamp   product_category_name  \
# 0           2017-09-13 08:59:02              cool_stuff
# 1           2017-04-26 10:53:06                pet_shop
# 2           2018-01-14 14:33:31        moveis_decoracao
# 3           2018-08-08 10:00:35              perfumaria
# 4           2017-02-04 13:57:51      ferramentas_jardim
# ...                         ...                     ...
# 117599      2018-04-23 13:57:06   utilidades_domesticas
# 117600      2018-07-14 10:26:46  informatica_acessorios
# 117601      2017-10-23 17:07:56           esporte_lazer
# 117602      2017-08-14 23:02:59  informatica_acessorios
# 117603      2018-06-09 17:00:18         cama_mesa_banho
#
#        product_category_name_english  payment_value payment_type  \
# 0                         cool_stuff          72.19  credit_card
# 1                           pet_shop         259.83  credit_card
# 2                    furniture_decor         216.87  credit_card
# 3                          perfumery          25.78  credit_card
# 4                       garden_tools         218.04  credit_card
# ...                              ...            ...          ...
# 117599                    housewares         343.40       boleto
# 117600         computers_accessories         386.53       boleto
# 117601                sports_leisure         116.85  credit_card
# 117602         computers_accessories          64.71  credit_card
# 117603                bed_bath_table          55.79  credit_card
#
#         payment_installments                customer_unique_id  \
# 0                        2.0  871766c5855e863f6eccc05f988b23cb
# 1                        3.0  eb28e67c4c0b83846050ddfb8a35d051
# 2                        5.0  3818d81c6709e39d06b2738a8d3a2474
# 3                        2.0  af861d436cfc08b2c2ddefd0ba074622
# 4                        3.0  64b576fb70d441e8f1b2d7d446e483c5
# ...                      ...                               ...
# 117599                   1.0  0c9aeda10a71f369396d0c04dce13a64
# 117600                   1.0  0da9fe112eae0c74d3ba1fe16de0988b
# 117601                   3.0  cd79b407828f02fdbba457111c38e4c4
# 117602                   3.0  eb803377c9315b564bdedad672039306
# 117603                   1.0  cd76a00d8e3ca5e6ab9ed9ecb6667ac4
#
#                 customer_city customer_state
# 0       campos dos goytacazes             RJ
# 1             santa fe do sul             SP
# 2               para de minas             MG
# 3                     atibaia             SP
# 4             varzea paulista             SP
# ...                       ...            ...
# 117599               sao luis             MA
# 117600               curitiba             PR
# 117601              sao paulo             SP
# 117602                vinhedo             SP
# 117603               botucatu             SP
#
# [117604 rows x 18 columns]

# %%
# [6] Adds seller_city and seller_state columns to 'data' based on seller_id
def add_order_info6(data, sellers):
    data = data.merge(sellers[['seller_id', 'seller_city', 'seller_state']], on='seller_id', how='left')
    return data

data = add_order_info6(data, sellers)
data
# Out:
#                                 order_id  order_item_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214              1
# 1       00018f77f2f0320c557190d7a144bdd3              1
# 2       000229ec398224ef6ca0657da4fc703e              1
# 3       00024acbcdf0a6daa1e931b038114c75              1
# 4       00042b26cf59d7ce69dfabb4e55b4fd9              1
# ...                                  ...            ...
# 117599  fffc94f6ce00a00581880bf54a75a037              1
# 117600  fffcd46ef2263f404302a634eb57f7eb              1
# 117601  fffce4705a9662cd70adb13d4a31832d              1
# 117602  fffe18544ffabc95dfada21779c9644f              1
# 117603  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 0       4244733e06e7ecb4970a6e2683c13e61  48436dade18ac8b2bce089ec2a041202
# 1       e5f2d52b802189ee658865ca93d83a8f  dd7ddc04e1b6c2c614352b383efe2d36
# 2       c777355d18b72b67abbeef9df44fd0fd  5b51032eddd242adc84c38acab88f23d
# 3       7634da152a4610f1595efa32f14722fc  9d7a1d34a5052409006425275ba1c2b4
# 4       ac6c3623068f30de03045865e4e10089  df560393f3a51e74553ab94004ba5c87
# ...                                  ...                               ...
# 117599  4aa6014eceb682077f9dc4bffebc05b0  b8bc237ba3788b23da09c0f1f3a3288c
# 117600  32e07fd915822b0765e448c4dd74c828  f3c38ab652836d21de61fb8314b69182
# 117601  72a30483855e2eafc67aee5dc2560482  c3cfdc648177fdbbbb35635a37472c53
# 117602  9c422a519119dcad7575db5af1ba540e  2b3e4a2a3ea8e01938cabda2a3e5cc79
# 117603  350688d9dc1e75ff97be326363655e01  f7ccf836d21b2fb1de37564105216cc1
#
#         shipping_limit_date   price  freight_value  \
# 0       2017-09-19 09:45:35   58.90          13.29
# 1       2017-05-03 11:05:13  239.90          19.93
# 2       2018-01-18 14:48:30  199.00          17.87
# 3       2018-08-15 10:10:18   12.99          12.79
# 4       2017-02-13 13:57:51  199.90          18.14
# ...                     ...     ...            ...
# 117599  2018-05-02 04:11:01  299.99          43.41
# 117600  2018-07-20 04:31:48  350.00          36.53
# 117601  2017-10-30 17:14:25   99.90          16.95
# 117602  2017-08-21 00:04:32   55.99           8.72
# 117603  2018-06-12 17:10:13   43.00          12.79
#
#                              customer_id order_status  \
# 0       3ce436f183e68e07877b285a838db11a    delivered
# 1       f6dd3ec061db4e3987629fe6b26e5cce    delivered
# 2       6489ae5e4333f3693df5ad4372dab6d3    delivered
# 3       d4eb9395c8c0431ee92fce09860c5a06    delivered
# 4       58dbd0b2d70206bf40e62cd34e84d795    delivered
# ...                                  ...          ...
# 117599  b51593916b4b8e0d6f66f2ae24f2673d    delivered
# 117600  84c5d4fbaf120aae381fad077416eaa0    delivered
# 117601  29309aa813182aaddc9b259e31b870e6    delivered
# 117602  b5e6afd5a41800fdf401e0272ca74655    delivered
# 117603  96d649da0cc4ff33bb408b199d4c7dcf    delivered
#
#        order_purchase_timestamp   product_category_name  \
# 0           2017-09-13 08:59:02              cool_stuff
# 1           2017-04-26 10:53:06                pet_shop
# 2           2018-01-14 14:33:31        moveis_decoracao
# 3           2018-08-08 10:00:35              perfumaria
# 4           2017-02-04 13:57:51      ferramentas_jardim
# ...                         ...                     ...
# 117599      2018-04-23 13:57:06   utilidades_domesticas
# 117600      2018-07-14 10:26:46  informatica_acessorios
# 117601      2017-10-23 17:07:56           esporte_lazer
# 117602      2017-08-14 23:02:59  informatica_acessorios
# 117603      2018-06-09 17:00:18         cama_mesa_banho
#
#        product_category_name_english  payment_value payment_type  \
# 0                         cool_stuff          72.19  credit_card
# 1                           pet_shop         259.83  credit_card
# 2                    furniture_decor         216.87  credit_card
# 3                          perfumery          25.78  credit_card
# 4                       garden_tools         218.04  credit_card
# ...                              ...            ...          ...
# 117599                    housewares         343.40       boleto
# 117600         computers_accessories         386.53       boleto
# 117601                sports_leisure         116.85  credit_card
# 117602         computers_accessories          64.71  credit_card
# 117603                bed_bath_table          55.79  credit_card
#
#         payment_installments                customer_unique_id  \
# 0                        2.0  871766c5855e863f6eccc05f988b23cb
# 1                        3.0  eb28e67c4c0b83846050ddfb8a35d051
# 2                        5.0  3818d81c6709e39d06b2738a8d3a2474
# 3                        2.0  af861d436cfc08b2c2ddefd0ba074622
# 4                        3.0  64b576fb70d441e8f1b2d7d446e483c5
# ...                      ...                               ...
# 117599                   1.0  0c9aeda10a71f369396d0c04dce13a64
# 117600                   1.0  0da9fe112eae0c74d3ba1fe16de0988b
# 117601                   3.0  cd79b407828f02fdbba457111c38e4c4
# 117602                   3.0  eb803377c9315b564bdedad672039306
# 117603                   1.0  cd76a00d8e3ca5e6ab9ed9ecb6667ac4
#
#                 customer_city customer_state    seller_city seller_state
# 0       campos dos goytacazes             RJ  volta redonda           SP
# 1             santa fe do sul             SP      sao paulo           SP
# 2               para de minas             MG  borda da mata           MG
# 3                     atibaia             SP         franca           SP
# 4             varzea paulista             SP         loanda           PR
# ...                       ...            ...            ...          ...
# 117599               sao luis             MA         itajai           SC
# 117600               curitiba             PR      sao paulo           SP
# 117601              sao paulo             SP       curitiba           PR
# 117602                vinhedo             SP      sao paulo           SP
# 117603               botucatu             SP       ibitinga           SP
#
# [117604 rows x 20 columns]

# %%
# Define the desired order columns
reorder_column = ['order_id', 'customer_id', 'customer_unique_id', 'customer_city', 'customer_state','product_id', 'seller_id', 'seller_city', 'seller_state', 'shipping_limit_date', 'order_purchase_timestamp',
                   'order_status', 'product_category_name', 'product_category_name_english', 'freight_value', 'order_item_id', 'price', 'payment_value', 'payment_type', 'payment_installments']

# Reorder the DataFrame
data = data[reorder_column]
data
# Out:
#                                 order_id                       customer_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214  3ce436f183e68e07877b285a838db11a
# 1       00018f77f2f0320c557190d7a144bdd3  f6dd3ec061db4e3987629fe6b26e5cce
# 2       000229ec398224ef6ca0657da4fc703e  6489ae5e4333f3693df5ad4372dab6d3
# 3       00024acbcdf0a6daa1e931b038114c75  d4eb9395c8c0431ee92fce09860c5a06
# 4       00042b26cf59d7ce69dfabb4e55b4fd9  58dbd0b2d70206bf40e62cd34e84d795
# ...                                  ...                               ...
# 117599  fffc94f6ce00a00581880bf54a75a037  b51593916b4b8e0d6f66f2ae24f2673d
# 117600  fffcd46ef2263f404302a634eb57f7eb  84c5d4fbaf120aae381fad077416eaa0
# 117601  fffce4705a9662cd70adb13d4a31832d  29309aa813182aaddc9b259e31b870e6
# 117602  fffe18544ffabc95dfada21779c9644f  b5e6afd5a41800fdf401e0272ca74655
# 117603  fffe41c64501cc87c801fd61db3f6244  96d649da0cc4ff33bb408b199d4c7dcf
#
#                       customer_unique_id          customer_city  \
# 0       871766c5855e863f6eccc05f988b23cb  campos dos goytacazes
# 1       eb28e67c4c0b83846050ddfb8a35d051        santa fe do sul
# 2       3818d81c6709e39d06b2738a8d3a2474          para de minas
# 3       af861d436cfc08b2c2ddefd0ba074622                atibaia
# 4       64b576fb70d441e8f1b2d7d446e483c5        varzea paulista
# ...                                  ...                    ...
# 117599  0c9aeda10a71f369396d0c04dce13a64               sao luis
# 117600  0da9fe112eae0c74d3ba1fe16de0988b               curitiba
# 117601  cd79b407828f02fdbba457111c38e4c4              sao paulo
# 117602  eb803377c9315b564bdedad672039306                vinhedo
# 117603  cd76a00d8e3ca5e6ab9ed9ecb6667ac4               botucatu
#
#        customer_state                        product_id  \
# 0                  RJ  4244733e06e7ecb4970a6e2683c13e61
# 1                  SP  e5f2d52b802189ee658865ca93d83a8f
# 2                  MG  c777355d18b72b67abbeef9df44fd0fd
# 3                  SP  7634da152a4610f1595efa32f14722fc
# 4                  SP  ac6c3623068f30de03045865e4e10089
# ...               ...                               ...
# 117599             MA  4aa6014eceb682077f9dc4bffebc05b0
# 117600             PR  32e07fd915822b0765e448c4dd74c828
# 117601             SP  72a30483855e2eafc67aee5dc2560482
# 117602             SP  9c422a519119dcad7575db5af1ba540e
# 117603             SP  350688d9dc1e75ff97be326363655e01
#
#                                seller_id    seller_city seller_state  \
# 0       48436dade18ac8b2bce089ec2a041202  volta redonda           SP
# 1       dd7ddc04e1b6c2c614352b383efe2d36      sao paulo           SP
# 2       5b51032eddd242adc84c38acab88f23d  borda da mata           MG
# 3       9d7a1d34a5052409006425275ba1c2b4         franca           SP
# 4       df560393f3a51e74553ab94004ba5c87         loanda           PR
# ...                                  ...            ...          ...
# 117599  b8bc237ba3788b23da09c0f1f3a3288c         itajai           SC
# 117600  f3c38ab652836d21de61fb8314b69182      sao paulo           SP
# 117601  c3cfdc648177fdbbbb35635a37472c53       curitiba           PR
# 117602  2b3e4a2a3ea8e01938cabda2a3e5cc79      sao paulo           SP
# 117603  f7ccf836d21b2fb1de37564105216cc1       ibitinga           SP
#
#         shipping_limit_date order_purchase_timestamp order_status  \
# 0       2017-09-19 09:45:35      2017-09-13 08:59:02    delivered
# 1       2017-05-03 11:05:13      2017-04-26 10:53:06    delivered
# 2       2018-01-18 14:48:30      2018-01-14 14:33:31    delivered
# 3       2018-08-15 10:10:18      2018-08-08 10:00:35    delivered
# 4       2017-02-13 13:57:51      2017-02-04 13:57:51    delivered
# ...                     ...                      ...          ...
# 117599  2018-05-02 04:11:01      2018-04-23 13:57:06    delivered
# 117600  2018-07-20 04:31:48      2018-07-14 10:26:46    delivered
# 117601  2017-10-30 17:14:25      2017-10-23 17:07:56    delivered
# 117602  2017-08-21 00:04:32      2017-08-14 23:02:59    delivered
# 117603  2018-06-12 17:10:13      2018-06-09 17:00:18    delivered
#
#          product_category_name product_category_name_english  freight_value  \
# 0                   cool_stuff                    cool_stuff          13.29
# 1                     pet_shop                      pet_shop          19.93
# 2             moveis_decoracao               furniture_decor          17.87
# 3                   perfumaria                     perfumery          12.79
# 4           ferramentas_jardim                  garden_tools          18.14
# ...                        ...                           ...            ...
# 117599   utilidades_domesticas                    housewares          43.41
# 117600  informatica_acessorios         computers_accessories          36.53
# 117601           esporte_lazer                sports_leisure          16.95
# 117602  informatica_acessorios         computers_accessories           8.72
# 117603         cama_mesa_banho                bed_bath_table          12.79
#
#         order_item_id   price  payment_value payment_type  \
# 0                   1   58.90          72.19  credit_card
# 1                   1  239.90         259.83  credit_card
# 2                   1  199.00         216.87  credit_card
# 3                   1   12.99          25.78  credit_card
# 4                   1  199.90         218.04  credit_card
# ...               ...     ...            ...          ...
# 117599              1  299.99         343.40       boleto
# 117600              1  350.00         386.53       boleto
# 117601              1   99.90         116.85  credit_card
# 117602              1   55.99          64.71  credit_card
# 117603              1   43.00          55.79  credit_card
#
#         payment_installments
# 0                        2.0
# 1                        3.0
# 2                        5.0
# 3                        2.0
# 4                        3.0
# ...                      ...
# 117599                   1.0
# 117600                   1.0
# 117601                   3.0
# 117602                   3.0
# 117603                   1.0
#
# [117604 rows x 20 columns]

# %%
# Drop the specified columns that not used
df = data.drop(columns=['shipping_limit_date', 'product_category_name'])
df
# Out:
#                                 order_id                       customer_id  \
# 0       00010242fe8c5a6d1ba2dd792cb16214  3ce436f183e68e07877b285a838db11a
# 1       00018f77f2f0320c557190d7a144bdd3  f6dd3ec061db4e3987629fe6b26e5cce
# 2       000229ec398224ef6ca0657da4fc703e  6489ae5e4333f3693df5ad4372dab6d3
# 3       00024acbcdf0a6daa1e931b038114c75  d4eb9395c8c0431ee92fce09860c5a06
# 4       00042b26cf59d7ce69dfabb4e55b4fd9  58dbd0b2d70206bf40e62cd34e84d795
# ...                                  ...                               ...
# 117599  fffc94f6ce00a00581880bf54a75a037  b51593916b4b8e0d6f66f2ae24f2673d
# 117600  fffcd46ef2263f404302a634eb57f7eb  84c5d4fbaf120aae381fad077416eaa0
# 117601  fffce4705a9662cd70adb13d4a31832d  29309aa813182aaddc9b259e31b870e6
# 117602  fffe18544ffabc95dfada21779c9644f  b5e6afd5a41800fdf401e0272ca74655
# 117603  fffe41c64501cc87c801fd61db3f6244  96d649da0cc4ff33bb408b199d4c7dcf
#
#                       customer_unique_id          customer_city  \
# 0       871766c5855e863f6eccc05f988b23cb  campos dos goytacazes
# 1       eb28e67c4c0b83846050ddfb8a35d051        santa fe do sul
# 2       3818d81c6709e39d06b2738a8d3a2474          para de minas
# 3       af861d436cfc08b2c2ddefd0ba074622                atibaia
# 4       64b576fb70d441e8f1b2d7d446e483c5        varzea paulista
# ...                                  ...                    ...
# 117599  0c9aeda10a71f369396d0c04dce13a64               sao luis
# 117600  0da9fe112eae0c74d3ba1fe16de0988b               curitiba
# 117601  cd79b407828f02fdbba457111c38e4c4              sao paulo
# 117602  eb803377c9315b564bdedad672039306                vinhedo
# 117603  cd76a00d8e3ca5e6ab9ed9ecb6667ac4               botucatu
#
#        customer_state                        product_id  \
# 0                  RJ  4244733e06e7ecb4970a6e2683c13e61
# 1                  SP  e5f2d52b802189ee658865ca93d83a8f
# 2                  MG  c777355d18b72b67abbeef9df44fd0fd
# 3                  SP  7634da152a4610f1595efa32f14722fc
# 4                  SP  ac6c3623068f30de03045865e4e10089
# ...               ...                               ...
# 117599             MA  4aa6014eceb682077f9dc4bffebc05b0
# 117600             PR  32e07fd915822b0765e448c4dd74c828
# 117601             SP  72a30483855e2eafc67aee5dc2560482
# 117602             SP  9c422a519119dcad7575db5af1ba540e
# 117603             SP  350688d9dc1e75ff97be326363655e01
#
#                                seller_id    seller_city seller_state  \
# 0       48436dade18ac8b2bce089ec2a041202  volta redonda           SP
# 1       dd7ddc04e1b6c2c614352b383efe2d36      sao paulo           SP
# 2       5b51032eddd242adc84c38acab88f23d  borda da mata           MG
# 3       9d7a1d34a5052409006425275ba1c2b4         franca           SP
# 4       df560393f3a51e74553ab94004ba5c87         loanda           PR
# ...                                  ...            ...          ...
# 117599  b8bc237ba3788b23da09c0f1f3a3288c         itajai           SC
# 117600  f3c38ab652836d21de61fb8314b69182      sao paulo           SP
# 117601  c3cfdc648177fdbbbb35635a37472c53       curitiba           PR
# 117602  2b3e4a2a3ea8e01938cabda2a3e5cc79      sao paulo           SP
# 117603  f7ccf836d21b2fb1de37564105216cc1       ibitinga           SP
#
#        order_purchase_timestamp order_status product_category_name_english  \
# 0           2017-09-13 08:59:02    delivered                    cool_stuff
# 1           2017-04-26 10:53:06    delivered                      pet_shop
# 2           2018-01-14 14:33:31    delivered               furniture_decor
# 3           2018-08-08 10:00:35    delivered                     perfumery
# 4           2017-02-04 13:57:51    delivered                  garden_tools
# ...                         ...          ...                           ...
# 117599      2018-04-23 13:57:06    delivered                    housewares
# 117600      2018-07-14 10:26:46    delivered         computers_accessories
# 117601      2017-10-23 17:07:56    delivered                sports_leisure
# 117602      2017-08-14 23:02:59    delivered         computers_accessories
# 117603      2018-06-09 17:00:18    delivered                bed_bath_table
#
#         freight_value  order_item_id   price  payment_value payment_type  \
# 0               13.29              1   58.90          72.19  credit_card
# 1               19.93              1  239.90         259.83  credit_card
# 2               17.87              1  199.00         216.87  credit_card
# 3               12.79              1   12.99          25.78  credit_card
# 4               18.14              1  199.90         218.04  credit_card
# ...               ...            ...     ...            ...          ...
# 117599          43.41              1  299.99         343.40       boleto
# 117600          36.53              1  350.00         386.53       boleto
# 117601          16.95              1   99.90         116.85  credit_card
# 117602           8.72              1   55.99          64.71  credit_card
# 117603          12.79              1   43.00          55.79  credit_card
#
#         payment_installments
# 0                        2.0
# 1                        3.0
# 2                        5.0
# 3                        2.0
# 4                        3.0
# ...                      ...
# 117599                   1.0
# 117600                   1.0
# 117601                   3.0
# 117602                   3.0
# 117603                   1.0
#
# [117604 rows x 18 columns]

# %% [markdown]
# # 2. Data Pre-Processing

# %% [markdown]
# ## A. Describe the data

# %%
# General information of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 117604 entries, 0 to 117603
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       117604 non-null  object
#  1   customer_id                    117604 non-null  object
#  2   customer_unique_id             117604 non-null  object
#  3   customer_city                  117604 non-null  object
#  4   customer_state                 117604 non-null  object
#  5   product_id                     117604 non-null  object
#  6   seller_id                      117604 non-null  object
#  7   seller_city                    117604 non-null  object
#  8   seller_state                   117604 non-null  object
#  9   order_purchase_timestamp       117604 non-null  object
#  10  order_status                   117604 non-null  object
#  11  product_category_name_english  115881 non-null  object
#  12  freight_value                  117604 non-null  float64
#  13  order_item_id                  117604 non-null  int64
#  14  price                          117604 non-null  float64
#  15  payment_value                  117601 non-null  float64
#  16  payment_type                   117601 non-null  object
#  17  payment_installments           117601 non-null  float64
# dtypes: float64(4), int64(1), object(13)
# memory usage: 16.2+ MB

# %% [markdown]
# ## B. Handle missing value

# %%
# Check the missing value
df.isna().sum()
# Out:
# order_id                            0
# customer_id                         0
# customer_unique_id                  0
# customer_city                       0
# customer_state                      0
# product_id                          0
# seller_id                           0
# seller_city                         0
# seller_state                        0
# order_purchase_timestamp            0
# order_status                        0
# product_category_name_english    1723
# freight_value                       0
# order_item_id                       0
# price                               0
# payment_value                       3
# payment_type                        3
# payment_installments                3
# dtype: int64

# %% [markdown]
# ### B1. payment_value

# %%
# Filter rows with missing values in 'payment_value'
missing_payment_value = df[df['payment_value'].isnull()]
missing_payment_value
# Out:
#                                order_id                       customer_id  \
# 88091  bfbd0f9bdef84302105ad712db648a6c  86dc2ffce2dfff336de2f386a786e574
# 88092  bfbd0f9bdef84302105ad712db648a6c  86dc2ffce2dfff336de2f386a786e574
# 88093  bfbd0f9bdef84302105ad712db648a6c  86dc2ffce2dfff336de2f386a786e574
#
#                      customer_unique_id         customer_city customer_state  \
# 88091  830d5b7aaa3b6f1e9ad63703bec97d23  sao joaquim da barra             SP
# 88092  830d5b7aaa3b6f1e9ad63703bec97d23  sao joaquim da barra             SP
# 88093  830d5b7aaa3b6f1e9ad63703bec97d23  sao joaquim da barra             SP
#
#                              product_id                         seller_id  \
# 88091  5a6b04657a4c5ee34285d1e4619a96b4  ecccfa2bb93b34a3bf033cc5d1dcdc69
# 88092  5a6b04657a4c5ee34285d1e4619a96b4  ecccfa2bb93b34a3bf033cc5d1dcdc69
# 88093  5a6b04657a4c5ee34285d1e4619a96b4  ecccfa2bb93b34a3bf033cc5d1dcdc69
#
#       seller_city seller_state order_purchase_timestamp order_status  \
# 88091    curitiba           PR      2016-09-15 12:16:38    delivered
# 88092    curitiba           PR      2016-09-15 12:16:38    delivered
# 88093    curitiba           PR      2016-09-15 12:16:38    delivered
#
#       product_category_name_english  freight_value  order_item_id  price  \
# 88091                 health_beauty           2.83              1  44.99
# 88092                 health_beauty           2.83              2  44.99
# 88093                 health_beauty           2.83              3  44.99
#
#        payment_value payment_type  payment_installments
# 88091            NaN          NaN                   NaN
# 88092            NaN          NaN                   NaN
# 88093            NaN          NaN                   NaN

# %%
def fill_missing_payment_value(df):
  """
  Fills missing values in payment_value based on price, order_item_id, and freight_value

  Args:q
    df: The DataFrame containing the data

  Returns:
    DataFrame: The DataFrame with filled missing values
  """

  df['payment_value'] = df['payment_value'].fillna(df.apply(lambda row: row['price'] * row['order_item_id'] + row['freight_value'], axis=1))
  return df

df = fill_missing_payment_value(df)

# %%
# Filter rows with missing values in 'payment_type'
missing_payment_type = df[df['payment_type'].isnull()]
missing_payment_type
# Out:
#                                order_id                       customer_id  \
# 88091  bfbd0f9bdef84302105ad712db648a6c  86dc2ffce2dfff336de2f386a786e574
# 88092  bfbd0f9bdef84302105ad712db648a6c  86dc2ffce2dfff336de2f386a786e574
# 88093  bfbd0f9bdef84302105ad712db648a6c  86dc2ffce2dfff336de2f386a786e574
#
#                      customer_unique_id         customer_city customer_state  \
# 88091  830d5b7aaa3b6f1e9ad63703bec97d23  sao joaquim da barra             SP
# 88092  830d5b7aaa3b6f1e9ad63703bec97d23  sao joaquim da barra             SP
# 88093  830d5b7aaa3b6f1e9ad63703bec97d23  sao joaquim da barra             SP
#
#                              product_id                         seller_id  \
# 88091  5a6b04657a4c5ee34285d1e4619a96b4  ecccfa2bb93b34a3bf033cc5d1dcdc69
# 88092  5a6b04657a4c5ee34285d1e4619a96b4  ecccfa2bb93b34a3bf033cc5d1dcdc69
# 88093  5a6b04657a4c5ee34285d1e4619a96b4  ecccfa2bb93b34a3bf033cc5d1dcdc69
#
#       seller_city seller_state order_purchase_timestamp order_status  \
# 88091    curitiba           PR      2016-09-15 12:16:38    delivered
# 88092    curitiba           PR      2016-09-15 12:16:38    delivered
# 88093    curitiba           PR      2016-09-15 12:16:38    delivered
#
#       product_category_name_english  freight_value  order_item_id  price  \
# 88091                 health_beauty           2.83              1  44.99
# 88092                 health_beauty           2.83              2  44.99
# 88093                 health_beauty           2.83              3  44.99
#
#        payment_value payment_type  payment_installments
# 88091          47.82          NaN                   NaN
# 88092          92.81          NaN                   NaN
# 88093         137.80          NaN                   NaN

# %% [markdown]
# ### B2. product_category_name_english

# %%
# Filter rows with missing values in 'payment_value'
missing_product_category_name_english = df[df['product_category_name_english'].isnull()]
missing_product_category_name_english
# Out:
#                                 order_id                       customer_id  \
# 125     0046e1d57f4c07c8c92ab26be8c3dfc0  ae55e228ded796581eccc67045516023
# 127     00482f2670787292280e0a8153d82467  baa4ed05f22ffb6c4a41b71b699a492c
# 134     004f5d8f238e8908e6864b874eda3391  a69c820c317aa348d781a9d6732afc23
# 144     0057199db02d1a5ef41bacbf41f8f63b  c664dc5de5b5f4184bc4ca0285b9f8fe
# 173     006cb7cafc99b29548d4f412c7f9f493  97dc92f1aae3a7db8b252d1b8466910e
# ...                                  ...                               ...
# 117253  ff24fec69b7f3d30f9dc1ab3aee7c179  442c6e15fe1e8e63a96598607c92bc35
# 117280  ff3024474be86400847879103757d1fd  945c975073e57fe39a636afbf6689bcc
# 117297  ff3a45ee744a7c1f8096d2e72c1a23e4  bb308532dc44f5973cd2caf17d15bd8c
# 117386  ff7b636282b98e0aa524264b295ed928  eb09a9c966e7801d1ab6ccb15baa96ef
# 117454  ffa5e4c604dea4f0a59d19cc2322ac19  665fe3b7ab435cda0fad0c3cbb1c51dd
#
#                       customer_unique_id   customer_city customer_state  \
# 125     b0efd7adeb04d15b16edaedd11215d40       sao paulo             SP
# 127     d4c784ecad19dfe09e63ffaf9ada82a3    juiz de fora             MG
# 134     17726716a98c98a7806b43a789820245         corumba             MS
# 144     9a5b186787a143669398bd8083720c21           sinop             MT
# 173     d5faae3f913e775994e53068992969b5        brasilia             DF
# ...                                  ...             ...            ...
# 117253  ae76d876d1067aa49fa661723d824ed5  jaragua do sul             SC
# 117280  7ae8e196478928ab8223458a90681d26        campinas             SP
# 117297  367879109f7a4aac09ac25b29d133d3a   volta redonda             RJ
# 117386  3dceeb3d4179741a2989416284356e63        brasilia             DF
# 117454  29d4565784c57f7afdd2d646af68f6d7         goiania             GO
#
#                               product_id                         seller_id  \
# 125     ff6caf9340512b8bf6d2a2a6df032cfa  38e6dada03429a47197d5d584d793b41
# 127     a9c404971d1a5b1cbc2e4070e02731fd  702835e4b785b67a084280efca355756
# 134     5a848e4ab52fd5445cdc07aab1c40e48  c826c40d7b19f62a09e2d7c5e7295ee2
# 144     41eee23c25f7a574dfaf8d5c151dbb12  e5a3438891c0bfdb9394643f95273d8e
# 173     e10758160da97891c2fdcbc35f0f031d  323ce52b5b81df2cd804b017b7f09aa7
# ...                                  ...                               ...
# 117253  5a848e4ab52fd5445cdc07aab1c40e48  c826c40d7b19f62a09e2d7c5e7295ee2
# 117280  f9b1795281ce51b1cf39ef6d101ae8ab  3771c85bac139d2344864ede5d9341e3
# 117297  b61d1388a17e3f547d2bc218df02335b  07017df32dc5f2f1d2801e579548d620
# 117386  431df35e52c10451171d8037482eeb43  6cd68b3ed6d59aaa9fece558ad360c0a
# 117454  bd421826916d3e1d445cb860cea3c0fb  59cd88080b93f3c18508673122d26169
#
#            seller_city seller_state order_purchase_timestamp order_status  \
# 125          sao paulo           SP      2017-09-26 15:24:03    delivered
# 127       juiz de fora           MG      2017-02-13 16:18:07    delivered
# 134          guarulhos           SP      2018-02-27 12:16:30    delivered
# 144            limeira           SP      2018-01-18 17:05:30    delivered
# 173          sao paulo           SP      2018-02-17 14:22:34    delivered
# ...                ...          ...                      ...          ...
# 117253       guarulhos           SP      2018-01-26 14:41:14    delivered
# 117280        sorocaba           SP      2017-11-11 15:18:16    delivered
# 117297     joao pessoa           PB      2017-05-03 07:08:50    delivered
# 117386  belo horizonte           MG      2018-02-17 14:46:29    delivered
# 117454    praia grande           SP      2017-12-04 21:45:30    delivered
#
#        product_category_name_english  freight_value  order_item_id   price  \
# 125                              NaN           7.78              1    7.79
# 127                              NaN          10.96              1    7.60
# 134                              NaN          15.61              1  122.99
# 144                              NaN          16.79              1   20.30
# 173                              NaN          14.14              1   56.00
# ...                              ...            ...            ...     ...
# 117253                           NaN          15.61              1  122.99
# 117280                           NaN           9.94              1   39.90
# 117297                           NaN          21.42              1  139.00
# 117386                           NaN          15.11              1   49.90
# 117454                           NaN          15.10              2   29.99
#
#         payment_value payment_type  payment_installments
# 125             15.57  credit_card                   1.0
# 127             18.56       boleto                   1.0
# 134            138.60       boleto                   1.0
# 144             37.09       boleto                   1.0
# 173             70.14  credit_card                   3.0
# ...               ...          ...                   ...
# 117253         138.60       boleto                   1.0
# 117280          49.84       boleto                   1.0
# 117297         160.42  credit_card                   3.0
# 117386          65.01  credit_card                   6.0
# 117454          90.18  credit_card                   1.0
#
# [1723 rows x 18 columns]

# %%
# Check if all product_id in missing_product_category_name_english are NaN or empty in df dataframe
for product_id in missing_product_category_name_english['product_id'].unique():
    if product_id in df['product_id'].unique():
        product_category_name_english_values = df[df['product_id'] == product_id]['product_category_name_english']
        if not product_category_name_english_values.isna().all() and not product_category_name_english_values.eq('').all():
            print(f"product_id {product_id} has non-empty values in product_category_name_english")
    else:
        print(f"product_id {product_id} not found in df")

# %%
# Example if all product_id in missing_product_category_name_english are NaN or empty in df dataframe
product_example = df[df['product_id'] == 'ff6caf9340512b8bf6d2a2a6df032cfa']
product_example
# Out:
#                               order_id                       customer_id  \
# 125   0046e1d57f4c07c8c92ab26be8c3dfc0  ae55e228ded796581eccc67045516023
# 5831  0ca8999f0176e37f35b6e49a9b2569da  750f02af7b06bb81d84d3e44b9afc6d3
# 5835  0ca8999f0176e37f35b6e49a9b2569da  750f02af7b06bb81d84d3e44b9afc6d3
#
#                     customer_unique_id customer_city customer_state  \
# 125   b0efd7adeb04d15b16edaedd11215d40     sao paulo             SP
# 5831  dbf27222f9c7369aaebf2fe82abf4b49     sao paulo             SP
# 5835  dbf27222f9c7369aaebf2fe82abf4b49     sao paulo             SP
#
#                             product_id                         seller_id  \
# 125   ff6caf9340512b8bf6d2a2a6df032cfa  38e6dada03429a47197d5d584d793b41
# 5831  ff6caf9340512b8bf6d2a2a6df032cfa  38e6dada03429a47197d5d584d793b41
# 5835  ff6caf9340512b8bf6d2a2a6df032cfa  38e6dada03429a47197d5d584d793b41
#
#      seller_city seller_state order_purchase_timestamp order_status  \
# 125    sao paulo           SP      2017-09-26 15:24:03    delivered
# 5831   sao paulo           SP      2017-10-06 10:52:01    delivered
# 5835   sao paulo           SP      2017-10-06 10:52:01    delivered
#
#      product_category_name_english  freight_value  order_item_id  price  \
# 125                            NaN           7.78              1   7.79
# 5831                           NaN           8.85              1   7.79
# 5835                           NaN           8.85              5   7.79
#
#       payment_value payment_type  payment_installments
# 125           15.57  credit_card                   1.0
# 5831          98.80  credit_card                   2.0
# 5835          98.80  credit_card                   2.0

# %%
# Then fill missing values in 'product_category_name_english' with 'others' value
df['product_category_name_english'].fillna('others', inplace=True)

# %% [markdown]
# Missing values in the product_category_name_english column can be filled with the category "Other" since all entries in this column for missing products are either null or empty.

# %% [markdown]
# ### B3. payment_type and payment_installments

# %%
def count_payment_types(df):
  """Counts unique payment_type and their totals

  Args:
    df: The DataFrame containing the payment_type column

  Returns:
    pandas.Series: A Series with payment types as index and counts as values
  """

  payment_type_counts = df['payment_type'].value_counts()
  return payment_type_counts

payment_type_counts = count_payment_types(df)
print(payment_type_counts)
# Out:
# payment_type
# credit_card    86769
# boleto         22867
# voucher         6274
# debit_card      1691
# Name: count, dtype: int64

# %%
# Counts unique payment_installments and their totals
def count_payment_installments(df):

  payment_installments_counts = df['payment_installments'].value_counts()
  return payment_installments_counts

payment_installments_counts = count_payment_installments(df)
print(payment_installments_counts)
# Out:
# payment_installments
# 1.0     58617
# 2.0     13722
# 3.0     11756
# 4.0      7979
# 10.0     6845
# 5.0      6017
# 8.0      5063
# 6.0      4617
# 7.0      1828
# 9.0       726
# 12.0      163
# 15.0       92
# 18.0       38
# 24.0       34
# 11.0       25
# 20.0       21
# 13.0       18
# 14.0       16
# 17.0        7
# 16.0        7
# 21.0        5
# 0.0         3
# 23.0        1
# 22.0        1
# Name: count, dtype: int64

# %%
def fill_missing_with_mode(df):
  """
  Fills missing values in payment_type and payment_installments with their mode

  Args:
    df: The DataFrame containing the data

  Returns:
    DataFrame: The DataFrame with filled missing values
  """

  for col in ['payment_type', 'payment_installments']:
    mode_value = df[col].mode().iloc[0]  # Get the mode
    df[col].fillna(mode_value, inplace=True)

  return df
df = fill_missing_with_mode(df)

# %%
# Check the missing value
df.isna().sum()
# Out:
# order_id                         0
# customer_id                      0
# customer_unique_id               0
# customer_city                    0
# customer_state                   0
# product_id                       0
# seller_id                        0
# seller_city                      0
# seller_state                     0
# order_purchase_timestamp         0
# order_status                     0
# product_category_name_english    0
# freight_value                    0
# order_item_id                    0
# price                            0
# payment_value                    0
# payment_type                     0
# payment_installments             0
# dtype: int64

# %% [markdown]
# ## C. Check duplicate data

# %%
# See whether there is duplicate data or not
df.duplicated().sum()
# Out:
# 684

# %%
duplicates = df[df.duplicated(keep=False)]
duplicates
# Out:
#                                 order_id                       customer_id  \
# 310     00bd50cdd31bd22e9081e6e2d5b3577b  1e47b918581b562a9d8d9f85fcb9b1e5
# 311     00bd50cdd31bd22e9081e6e2d5b3577b  1e47b918581b562a9d8d9f85fcb9b1e5
# 321     00c405bd71187154a7846862f585a9d4  1ab52508d3c58d96241850142347b75f
# 322     00c405bd71187154a7846862f585a9d4  1ab52508d3c58d96241850142347b75f
# 323     00c405bd71187154a7846862f585a9d4  1ab52508d3c58d96241850142347b75f
# ...                                  ...                               ...
# 117079  fedcd9f7ccdc8cba3a18defedd1a5547  13aa59158da63ba0e93ec6ac2c07aacb
# 117088  fedcd9f7ccdc8cba3a18defedd1a5547  13aa59158da63ba0e93ec6ac2c07aacb
# 117093  fedcd9f7ccdc8cba3a18defedd1a5547  13aa59158da63ba0e93ec6ac2c07aacb
# 117094  fedcd9f7ccdc8cba3a18defedd1a5547  13aa59158da63ba0e93ec6ac2c07aacb
# 117098  fedcd9f7ccdc8cba3a18defedd1a5547  13aa59158da63ba0e93ec6ac2c07aacb
#
#                       customer_unique_id     customer_city customer_state  \
# 310     71a5182c33ade63d4f8b42f432b834c0          campinas             SP
# 311     71a5182c33ade63d4f8b42f432b834c0          campinas             SP
# 321     58b051c30d684ac12a2049a49c856203  feira de santana             BA
# 322     58b051c30d684ac12a2049a49c856203  feira de santana             BA
# 323     58b051c30d684ac12a2049a49c856203  feira de santana             BA
# ...                                  ...               ...            ...
# 117079  6fbc7cdadbb522125f4b27ae9dee4060    rio de janeiro             RJ
# 117088  6fbc7cdadbb522125f4b27ae9dee4060    rio de janeiro             RJ
# 117093  6fbc7cdadbb522125f4b27ae9dee4060    rio de janeiro             RJ
# 117094  6fbc7cdadbb522125f4b27ae9dee4060    rio de janeiro             RJ
# 117098  6fbc7cdadbb522125f4b27ae9dee4060    rio de janeiro             RJ
#
#                               product_id                         seller_id  \
# 310     e70f7c188cd2c0f01a1f6b35411cc481  6560211a19b47992c3666cc44a7e94c0
# 311     e70f7c188cd2c0f01a1f6b35411cc481  6560211a19b47992c3666cc44a7e94c0
# 321     c4cf7c2e1f190d51517eba7e8211c8e6  f3295428338a40977a03f555246a70f4
# 322     c4cf7c2e1f190d51517eba7e8211c8e6  f3295428338a40977a03f555246a70f4
# 323     c4cf7c2e1f190d51517eba7e8211c8e6  f3295428338a40977a03f555246a70f4
# ...                                  ...                               ...
# 117079  0554911df28fda9fd668ce5ba5949695  7c67e1448b00f6e969d365cea6b010ab
# 117088  0554911df28fda9fd668ce5ba5949695  7c67e1448b00f6e969d365cea6b010ab
# 117093  0554911df28fda9fd668ce5ba5949695  7c67e1448b00f6e969d365cea6b010ab
# 117094  0554911df28fda9fd668ce5ba5949695  7c67e1448b00f6e969d365cea6b010ab
# 117098  0554911df28fda9fd668ce5ba5949695  7c67e1448b00f6e969d365cea6b010ab
#
#             seller_city seller_state order_purchase_timestamp order_status  \
# 310           sao paulo           SP      2018-01-14 22:31:54    delivered
# 311           sao paulo           SP      2018-01-14 22:31:54    delivered
# 321             vitoria           ES      2017-10-23 14:59:46    delivered
# 322             vitoria           ES      2017-10-23 14:59:46    delivered
# 323             vitoria           ES      2017-10-23 14:59:46    delivered
# ...                 ...          ...                      ...          ...
# 117079  itaquaquecetuba           SP      2017-09-23 14:56:45    delivered
# 117088  itaquaquecetuba           SP      2017-09-23 14:56:45    delivered
# 117093  itaquaquecetuba           SP      2017-09-23 14:56:45    delivered
# 117094  itaquaquecetuba           SP      2017-09-23 14:56:45    delivered
# 117098  itaquaquecetuba           SP      2017-09-23 14:56:45    delivered
#
#        product_category_name_english  freight_value  order_item_id  price  \
# 310                    watches_gifts           7.80              1  78.00
# 311                    watches_gifts           7.80              1  78.00
# 321                    health_beauty          16.79              1  29.90
# 322                    health_beauty          16.79              1  29.90
# 323                    health_beauty          16.79              1  29.90
# ...                              ...            ...            ...    ...
# 117079              office_furniture          22.88              1  79.99
# 117088              office_furniture          22.88              2  79.99
# 117093              office_furniture          22.88              2  79.99
# 117094              office_furniture          22.88              2  79.99
# 117098              office_furniture          22.88              2  79.99
#
#         payment_value payment_type  payment_installments
# 310             40.46      voucher                   1.0
# 311             40.46      voucher                   1.0
# 321             20.00      voucher                   1.0
# 322             20.00      voucher                   1.0
# 323              0.10      voucher                   1.0
# ...               ...          ...                   ...
# 117079           9.76      voucher                   1.0
# 117088           8.42      voucher                   1.0
# 117093           8.42      voucher                   1.0
# 117094           9.76      voucher                   1.0
# 117098           9.76      voucher                   1.0
#
# [1030 rows x 18 columns]

# %%
# Drop the duplicate because the dataset will be redundant
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (116920, 18)

# %% [markdown]
# # 3. Exploratory Data Analyst

# %%
# Statistika descriptive for numeric data type
df.describe()
# Out:
#        freight_value  order_item_id          price  payment_value  \
# count  116920.000000  116920.000000  116920.000000  116920.000000
# mean       20.032307       1.195963     120.804801     173.502195
# std        15.834141       0.698372     184.485311     268.124616
# min         0.000000       1.000000       0.850000       0.000000
# 25%        13.080000       1.000000      39.900000      61.590000
# 50%        16.290000       1.000000      74.900000     108.860000
# 75%        21.180000       1.000000     134.900000     189.730000
# max       409.680000      21.000000    6735.000000   13664.080000
#
#        payment_installments
# count         116920.000000
# mean               2.950180
# std                2.778092
# min                0.000000
# 25%                1.000000
# 50%                2.000000
# 75%                4.000000
# max               24.000000

# %%
# Statistika descriptive for non-numeric (object) data type
df.describe(include=["object"])
# Out:
#                                 order_id                       customer_id  \
# count                             116920                            116920
# unique                             98666                             98666
# top     fedcd9f7ccdc8cba3a18defedd1a5547  13aa59158da63ba0e93ec6ac2c07aacb
# freq                                  34                                34
#
#                       customer_unique_id customer_city customer_state  \
# count                             116920        116920         116920
# unique                             95420          4110             27
# top     f9ae226291893fda10af7965268fb7f6     sao paulo             SP
# freq                                  35         18448          49237
#
#                               product_id                         seller_id  \
# count                             116920                            116920
# unique                             32951                              3095
# top     aca2eb7d00ea1a7b8ebd4e68314663af  4a3ca9315b744ce9f8e9374361493884
# freq                                 534                              2121
#
#        seller_city seller_state order_purchase_timestamp order_status  \
# count       116920       116920                   116920       116920
# unique         611           23                    98112            7
# top      sao paulo           SP      2017-09-23 14:56:45    delivered
# freq         29014        83388                       34       114368
#
#        product_category_name_english payment_type
# count                         116920       116920
# unique                            72            4
# top                   bed_bath_table  credit_card
# freq                           11726        86751

# %% [markdown]
# ## A. order_status condition

# %%
def analyze_order_status(df):
  """
  Counts unique order statuses, calculates percentages, and plots the results.

  Args:
    df: The DataFrame containing the order_status column.
  """

  # Count unique order statuses
  order_status_counts = df['order_status'].value_counts()

  # Calculate percentages
  order_status_percentages = (order_status_counts / order_status_counts.sum()) * 100

  # Create a DataFrame with counts and percentages
  order_status_summary = pd.DataFrame({'Count': order_status_counts, 'Percentage': order_status_percentages})

  # Plot the counts
  order_status_counts.plot(kind='bar', title='Order Status Counts')
  plt.ylabel('Count')
  plt.xlabel('Order Status')

  plt.show()

  return order_status_summary

# Example usage:
# Assuming you have a DataFrame named 'df'
analyze_order_status(df)
# Out:
#                Count  Percentage
# order_status
# delivered     114368   97.817311
# shipped         1238    1.058844
# canceled         565    0.483236
# invoiced         370    0.316456
# processing       369    0.315600
# unavailable        7    0.005987
# approved           3    0.002566

# %%
# Canceled and unavailable in order_status will be drop due to not affected in the performance transaction or sales in generate revenue

def filter_orders(df):
  """
  Filters a DataFrame to remove rows with 'canceled' or 'unavailable' order status.

  Args:
    df: The DataFrame containing the order data.

  Returns:
    DataFrame: The filtered DataFrame.
  """

  return df[~df['order_status'].isin(['canceled', 'unavailable'])]

# Example usage:
# Assuming you have a DataFrame named 'df'
df = filter_orders(df)
df.shape
# Out:
# (116348, 18)

# %% [markdown]
# Orders with canceled or unavailable statuses will be dropped due to their negligible impact on transaction performance and revenue generation.

# %% [markdown]
# ## B. Favorite payment_type

# %%
def analyze_payment_type(df):
  
  # Count unique order statuses
  payment_type_counts = df['payment_type'].value_counts()

  # Calculate percentages
  payment_type_percentages = (payment_type_counts / payment_type_counts.sum()) * 100

  # Create a DataFrame with counts and percentages
  payment_type_summary = pd.DataFrame({'Count': payment_type_counts, 'Percentage': payment_type_percentages})

  # Plot the counts
  payment_type_counts.plot(kind='bar', title='Payment Type Counts')
  plt.ylabel('Count')
  plt.xlabel('Payment Type')

  # Plot the percentages
  payment_type_percentages.plot(kind='bar', title='Payment Type Percentages')
  plt.ylabel('Percentage')
  plt.xlabel('Payment Type')

  plt.show()

  return payment_type_summary

# Example usage:
# Assuming you have a DataFrame named 'df'
analyze_payment_type(df)
# Out:
#               Count  Percentage
# payment_type
# credit_card   86309   74.181765
# boleto        22771   19.571458
# voucher        5583    4.798535
# debit_card     1685    1.448241

# %% [markdown]
# Credit cards remain the most popular payment method, accounting for 74.18% of transactions. To maintain customer satisfaction, consider expanding the range of credit cards accepted from different banks. Debit cards, while less preferred (1.45%), could see increased usage with the addition of more options from various banks, potentially subject to limitations.

# %% [markdown]
# ## C. Most city and state customers and sellers

# %% [markdown]
# ### C1. Customer city

# %%
city_customers = df.groupby('customer_city')['customer_unique_id'].nunique().reset_index(name='count')
city_customers['percentage'] = (city_customers['count'] / city_customers['count'].sum()) * 100
city_customers = city_customers.sort_values(by='count', ascending=False)
city_customers
# Out:
#                    customer_city  count  percentage
# 3587                   sao paulo  14761   15.521393
# 3146              rio de janeiro   6545    6.882157
# 452               belo horizonte   2641    2.777048
# 557                     brasilia   2051    2.156655
# 1141                    curitiba   1447    1.521540
# ...                          ...    ...         ...
# 2425                   mussurepe      1    0.001052
# 3313  santa quiteria do maranhao      1    0.001052
# 808                      caracol      1    0.001052
# 1705                     ipueira      1    0.001052
# 2064                     lamarao      1    0.001052
#
# [4109 rows x 3 columns]

# %% [markdown]
# ### C2. Customer state

# %%
state_customer = df.groupby('customer_state')['customer_unique_id'].nunique().reset_index(name='count')
state_customer['percentage'] = (state_customer['count'] / state_customer['count'].sum()) * 100
state_customer = state_customer.sort_values(by='count', ascending=False)
state_customer
# Out:
#    customer_state  count  percentage
# 25             SP  39747   41.829701
# 18             RJ  12241   12.882415
# 10             MG  11134   11.717410
# 22             RS   5233    5.507204
# 17             PR   4824    5.076773
# 23             SC   3501    3.684449
# 4              BA   3244    3.413982
# 6              DF   2057    2.164785
# 7              ES   1950    2.052178
# 8              GO   1934    2.035340
# 15             PE   1600    1.683838
# 5              CE   1301    1.369171
# 13             PA    944    0.993465
# 12             MT    872    0.917692
# 9              MA    715    0.752465
# 11             MS    687    0.722998
# 14             PB    516    0.543038
# 16             PI    478    0.503047
# 19             RN    471    0.495680
# 1              AL    399    0.419907
# 24             SE    338    0.355711
# 26             TO    271    0.285200
# 20             RO    234    0.246261
# 2              AM    142    0.149441
# 0              AC     77    0.081035
# 3              AP     67    0.070511
# 21             RR     44    0.046306

# %% [markdown]
# ### C3. Seller city

# %%
city_seller = df.groupby('seller_city')['customer_unique_id'].nunique().reset_index(name='count')
city_seller['percentage'] = (city_seller['count'] / city_customers['count'].sum()) * 100
city_seller = city_seller.sort_values(by='count', ascending=False)
city_seller
# Out:
#                                   seller_city  count  percentage
# 511                                 sao paulo  24112   25.354097
# 225                                  ibitinga   6359    6.686575
# 159                                  curitiba   2658    2.794923
# 477                               santo andre   2635    2.770738
# 64                             belo horizonte   2384    2.506809
# ..                                        ...    ...         ...
# 527                                       sbc      1    0.001052
# 526                                são paulo      1    0.001052
# 363  novo hamburgo, rio grande do sul, brasil      1    0.001052
# 366                                  oliveira      1    0.001052
# 0                                    04482255      1    0.001052
#
# [605 rows x 3 columns]

# %% [markdown]
# ### C4. Seller state

# %%
state_seller = df.groupby('seller_state')['customer_unique_id'].nunique().reset_index(name='count')
state_seller['percentage'] = (state_seller['count'] / state_seller['count'].sum()) * 100
state_seller = state_seller.sort_values(by='count', ascending=False)
state_seller
# Out:
#    seller_state  count  percentage
# 22           SP  67911   70.403276
# 8            MG   7793    8.078996
# 15           PR   7525    7.801161
# 16           RJ   4292    4.449513
# 20           SC   3626    3.759071
# 19           RS   1970    2.042297
# 4            DF    814    0.843873
# 2            BA    558    0.578478
# 6            GO    458    0.474808
# 13           PE    404    0.418826
# 7            MA    388    0.402239
# 5            ES    316    0.327597
# 10           MT    137    0.142028
# 3            CE     87    0.090193
# 17           RN     51    0.052872
# 9            MS     48    0.049762
# 12           PB     36    0.037321
# 18           RO     14    0.014514
# 14           PI     12    0.012440
# 21           SE      9    0.009330
# 11           PA      7    0.007257
# 1            AM      3    0.003110
# 0            AC      1    0.001037

# %% [markdown]
# ## D. Most purchased product_category

# %%
# Calculate sum of quantity by each product_category_name_english
most_product_category = df.groupby('product_category_name_english')['order_item_id'].sum().reset_index()
most_product_category = most_product_category.sort_values('order_item_id', ascending=False)

# Calculate the total sum of order_item_id
total_order_item_id = most_product_category['order_item_id'].sum()

# Create a new column for percentage
most_product_category['percentage'] = (most_product_category['order_item_id'] / total_order_item_id) * 100

# Rename the order_item_id column to total_item
most_product_category = most_product_category.rename(columns={'order_item_id': 'total_item'})

most_product_category
# Out:
#    product_category_name_english  total_item  percentage
# 7                 bed_bath_table       14381   10.338828
# 39               furniture_decor       11939    8.583219
# 43                 health_beauty       11336    8.149708
# 66                sports_leisure       10148    7.295628
# 15         computers_accessories       10105    7.264715
# ..                           ...         ...         ...
# 3          arts_and_craftmanship          26    0.018692
# 52                    la_cuisine          18    0.012941
# 11             cds_dvds_musicals          16    0.011503
# 29     fashion_childrens_clothes           8    0.005751
# 62         security_and_services           2    0.001438
#
# [72 rows x 3 columns]

# %% [markdown]
# ## E. The most expensive and the cheapest product

# %%
most_expensive_to_cheapest = df.sort_values(['product_category_name_english', 'price'], ascending=[True, False])[['product_category_name_english', 'price']]
most_expensive_to_cheapest
# Out:
#        product_category_name_english    price
# 99269     agro_industry_and_commerce  2990.00
# 72990     agro_industry_and_commerce  2399.00
# 89159     agro_industry_and_commerce  2199.00
# 11559     agro_industry_and_commerce  1899.00
# 16318     agro_industry_and_commerce  1476.30
# ...                              ...      ...
# 105173                 watches_gifts    14.90
# 105174                 watches_gifts    14.90
# 105175                 watches_gifts    14.90
# 117025                 watches_gifts    10.99
# 31444                  watches_gifts     8.99
#
# [116348 rows x 2 columns]

# %% [markdown]
# ## F. Correlation Matrix

# %%
# Select the desired columns for Correlation Matrix
selected_columns = ['freight_value', 'order_item_id', 'price', 'payment_value', 'payment_installments']

# Calculate and plo correlation matrix
corr_matrix = df[selected_columns].corr()
sns.heatmap(corr_matrix);

# %% [markdown]
# # 4. RFM or Clustering

# %% [markdown]
# ## A. Recency

# %%
# Check the date
print("Min Date", df["order_purchase_timestamp"].min(), "Max Date", df["order_purchase_timestamp"].max())
# Out:
# Min Date 2016-09-04 21:15:19 Max Date 2018-09-03 09:06:57

# %%
# Convert column order_purchase_timestamp to datetime format
df['order_purchase_timestamp'] = pd.to_datetime(df['order_purchase_timestamp'])

# Calculate total last days customer made a purchase or transaction
recency = (dt.datetime(2018, 9, 3) - df.groupby("customer_unique_id").agg({"order_purchase_timestamp":"max"})).rename(columns = {"order_purchase_timestamp":"Recency"})
recency["Recency"] = recency["Recency"].apply(lambda x: x.days)

# Reset the index to make 'customer_unique_id' a column
recency = recency.reset_index()
recency
# Out:
# C:\Users\ASUS\AppData\Local\Temp\ipykernel_5464\2691039314.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['order_purchase_timestamp'] = pd.to_datetime(df['order_purchase_timestamp'])
#                      customer_unique_id  Recency
# 0      0000366f3b9a7992bf8c76cfdf3221e2      115
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f      118
# 2      0000f46a3911fa3c0805444483337064      541
# 3      0000f6ccb0745a6a4b88665a16c9f078      325
# 4      0004aac84e0df4da2b147fca70cf8255      292
# ...                                 ...      ...
# 94978  fffcf5a5ff07b0908bd4e2dbc735a684      451
# 94979  fffea47cd6d3cc0a88bd621562a9d061      266
# 94980  ffff371b4d645b6ecea244b27531430a      572
# 94981  ffff5962728ec6157033ef9805bacc48      123
# 94982  ffffd2657e2aad2907e67c3e9daecbeb      488
#
# [94983 rows x 2 columns]

# %% [markdown]
# ## B. Frequency

# %%
# Calculate the frequency customer made a purchase or transaction by their order_id
freq = df.groupby("customer_unique_id").agg({"order_id":"nunique"}).rename(columns={"order_id": "Frequency"})
freq = freq.reset_index()
freq
# Out:
#                      customer_unique_id  Frequency
# 0      0000366f3b9a7992bf8c76cfdf3221e2          1
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f          1
# 2      0000f46a3911fa3c0805444483337064          1
# 3      0000f6ccb0745a6a4b88665a16c9f078          1
# 4      0004aac84e0df4da2b147fca70cf8255          1
# ...                                 ...        ...
# 94978  fffcf5a5ff07b0908bd4e2dbc735a684          1
# 94979  fffea47cd6d3cc0a88bd621562a9d061          1
# 94980  ffff371b4d645b6ecea244b27531430a          1
# 94981  ffff5962728ec6157033ef9805bacc48          1
# 94982  ffffd2657e2aad2907e67c3e9daecbeb          1
#
# [94983 rows x 2 columns]

# %% [markdown]
# ## C. Monetary

# %%
# Calculate the total payment_value by each customer_unique_id
monetary = df.groupby("customer_unique_id").agg({"payment_value":"sum"}).rename(columns={"payment_value":"Monetary"})
monetary = monetary.reset_index()
monetary
# Out:
#                      customer_unique_id  Monetary
# 0      0000366f3b9a7992bf8c76cfdf3221e2    141.90
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f     27.19
# 2      0000f46a3911fa3c0805444483337064     86.22
# 3      0000f6ccb0745a6a4b88665a16c9f078     43.62
# 4      0004aac84e0df4da2b147fca70cf8255    196.89
# ...                                 ...       ...
# 94978  fffcf5a5ff07b0908bd4e2dbc735a684   4134.84
# 94979  fffea47cd6d3cc0a88bd621562a9d061     84.58
# 94980  ffff371b4d645b6ecea244b27531430a    112.46
# 94981  ffff5962728ec6157033ef9805bacc48    133.69
# 94982  ffffd2657e2aad2907e67c3e9daecbeb     71.56
#
# [94983 rows x 2 columns]

# %%
# Merge recency, freq, and monetary DataFrames
rfm = pd.merge(recency, freq, on='customer_unique_id')
rfm = pd.merge(rfm, monetary, on='customer_unique_id')

# Now merged_df contains columns from all three DataFrames
rfm
# Out:
#                      customer_unique_id  Recency  Frequency  Monetary
# 0      0000366f3b9a7992bf8c76cfdf3221e2      115          1    141.90
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f      118          1     27.19
# 2      0000f46a3911fa3c0805444483337064      541          1     86.22
# 3      0000f6ccb0745a6a4b88665a16c9f078      325          1     43.62
# 4      0004aac84e0df4da2b147fca70cf8255      292          1    196.89
# ...                                 ...      ...        ...       ...
# 94978  fffcf5a5ff07b0908bd4e2dbc735a684      451          1   4134.84
# 94979  fffea47cd6d3cc0a88bd621562a9d061      266          1     84.58
# 94980  ffff371b4d645b6ecea244b27531430a      572          1    112.46
# 94981  ffff5962728ec6157033ef9805bacc48      123          1    133.69
# 94982  ffffd2657e2aad2907e67c3e9daecbeb      488          1     71.56
#
# [94983 rows x 4 columns]

# %%
# Create RFM Score
rfm["Recency_Score"] = pd.qcut(rfm["Recency"], 5, labels = [5, 4 , 3, 2, 1])
rfm["Frequency_Score"]= pd.qcut(rfm["Frequency"].rank(method="first"),5, labels=[1,2,3,4,5])
rfm["Monetary_Score"] = pd.qcut(rfm['Monetary'], 5, labels = [1, 2, 3, 4, 5])
rfm
# Out:
#                      customer_unique_id  Recency  Frequency  Monetary  \
# 0      0000366f3b9a7992bf8c76cfdf3221e2      115          1    141.90
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f      118          1     27.19
# 2      0000f46a3911fa3c0805444483337064      541          1     86.22
# 3      0000f6ccb0745a6a4b88665a16c9f078      325          1     43.62
# 4      0004aac84e0df4da2b147fca70cf8255      292          1    196.89
# ...                                 ...      ...        ...       ...
# 94978  fffcf5a5ff07b0908bd4e2dbc735a684      451          1   4134.84
# 94979  fffea47cd6d3cc0a88bd621562a9d061      266          1     84.58
# 94980  ffff371b4d645b6ecea244b27531430a      572          1    112.46
# 94981  ffff5962728ec6157033ef9805bacc48      123          1    133.69
# 94982  ffffd2657e2aad2907e67c3e9daecbeb      488          1     71.56
#
#       Recency_Score Frequency_Score Monetary_Score
# 0                 4               1              4
# 1                 4               1              1
# 2                 1               1              2
# 3                 2               1              1
# 4                 2               1              4
# ...             ...             ...            ...
# 94978             1               5              5
# 94979             3               5              2
# 94980             1               5              3
# 94981             4               5              3
# 94982             1               5              2
#
# [94983 rows x 7 columns]

# %%
# Define RFM Scores: Category
rfm["RFM_SCORE"] = (rfm['Recency_Score'].astype(str) + 
                     rfm['Frequency_Score'].astype(str) + 
                     rfm['Monetary_Score'].astype(str))
rfm
# Out:
#                      customer_unique_id  Recency  Frequency  Monetary  \
# 0      0000366f3b9a7992bf8c76cfdf3221e2      115          1    141.90
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f      118          1     27.19
# 2      0000f46a3911fa3c0805444483337064      541          1     86.22
# 3      0000f6ccb0745a6a4b88665a16c9f078      325          1     43.62
# 4      0004aac84e0df4da2b147fca70cf8255      292          1    196.89
# ...                                 ...      ...        ...       ...
# 94978  fffcf5a5ff07b0908bd4e2dbc735a684      451          1   4134.84
# 94979  fffea47cd6d3cc0a88bd621562a9d061      266          1     84.58
# 94980  ffff371b4d645b6ecea244b27531430a      572          1    112.46
# 94981  ffff5962728ec6157033ef9805bacc48      123          1    133.69
# 94982  ffffd2657e2aad2907e67c3e9daecbeb      488          1     71.56
#
#       Recency_Score Frequency_Score Monetary_Score RFM_SCORE
# 0                 4               1              4       414
# 1                 4               1              1       411
# 2                 1               1              2       112
# 3                 2               1              1       211
# 4                 2               1              4       214
# ...             ...             ...            ...       ...
# 94978             1               5              5       155
# 94979             3               5              2       352
# 94980             1               5              3       153
# 94981             4               5              3       453
# 94982             1               5              2       152
#
# [94983 rows x 8 columns]

# %%
# Cluster the segmentation of each customer_unique_id
seg_map = {
    r'[1-2][1-2]': 'Hibernating',
    r'[1-2][3-4]': 'At Risk',
    r'[1-2]5': 'Can\'t Loose',
    r'3[1-2]': 'About to Sleep',
    r'33': 'Need Attention',
    r'[3-4][4-5]': 'Loyal Customers',
    r'41': 'Promising',
    r'51': 'New Customers',
    r'[4-5][2-3]': 'Potential Loyalists',
    r'5[4-5]': 'Champions'
}

rfm['Segment'] = rfm['Recency_Score'].astype(str) + rfm['Frequency_Score'].astype(str)
rfm['Segment'] = rfm['Segment'].replace(seg_map, regex=True)
rfm
# Out:
#                      customer_unique_id  Recency  Frequency  Monetary  \
# 0      0000366f3b9a7992bf8c76cfdf3221e2      115          1    141.90
# 1      0000b849f77a49e4a4ce2b2a4ca5be3f      118          1     27.19
# 2      0000f46a3911fa3c0805444483337064      541          1     86.22
# 3      0000f6ccb0745a6a4b88665a16c9f078      325          1     43.62
# 4      0004aac84e0df4da2b147fca70cf8255      292          1    196.89
# ...                                 ...      ...        ...       ...
# 94978  fffcf5a5ff07b0908bd4e2dbc735a684      451          1   4134.84
# 94979  fffea47cd6d3cc0a88bd621562a9d061      266          1     84.58
# 94980  ffff371b4d645b6ecea244b27531430a      572          1    112.46
# 94981  ffff5962728ec6157033ef9805bacc48      123          1    133.69
# 94982  ffffd2657e2aad2907e67c3e9daecbeb      488          1     71.56
#
#       Recency_Score Frequency_Score Monetary_Score RFM_SCORE          Segment
# 0                 4               1              4       414        Promising
# 1                 4               1              1       411        Promising
# 2                 1               1              2       112      Hibernating
# 3                 2               1              1       211      Hibernating
# 4                 2               1              4       214      Hibernating
# ...             ...             ...            ...       ...              ...
# 94978             1               5              5       155      Can't Loose
# 94979             3               5              2       352  Loyal Customers
# 94980             1               5              3       153      Can't Loose
# 94981             4               5              3       453  Loyal Customers
# 94982             1               5              2       152      Can't Loose
#
# [94983 rows x 9 columns]

# %% [markdown]
# Based on Recency (R)
# - Hibernating: Customers who haven't made a purchase in a long time but have previously been active.
# - At Risk: Customers who haven't made a purchase recently, but their previous activity suggests they might churn if not re-engaged.
# - Can't Lose: Customers who have made a purchase recently but have a low overall purchase frequency.
#
# Based on Frequency (F)
# - About to Sleep: Customers who have made a purchase recently but have a declining frequency compared to their past.
# - Need Attention: Customers who have made a purchase recently but their frequency is significantly lower than their historical average.
#
# Based on Monetary (M)
# - Loyal Customers: Customers who have made multiple purchases and have spent a significant amount of money.
# - Promising: Customers who have made a few purchases but have spent a significant amount of money.
# - New Customers: Customers who have made their first purchase.
# - Potential Loyalists: Customers who have made a few purchases and have shown consistent spending behavior.
# - Champions: Customers who have made multiple purchases, spent a significant amount of money, and are likely to continue purchasing.

# %% [markdown]
# ## Summary Statistics

# %%
rfm_stats = rfm[["Segment","Recency","Frequency", "Monetary"]].groupby("Segment").agg(["mean","median","count", "std"])
rfm_stats.columns = rfm_stats.columns.map('_'.join).str.strip('|')
rfm_stats
# Out:
#                      Recency_mean  Recency_median  Recency_count  Recency_std  \
# Segment
# About to Sleep         224.474660           223.0           7498    26.457921
# At Risk                399.451511           387.0          15220    93.775922
# Can't Loose            398.969579           387.0           7429    93.484044
# Champions               49.562484            46.0           7698    25.762581
# Hibernating            400.267646           388.0          15244    93.889443
# Loyal Customers        182.867823           182.0          15222    49.401446
# Need Attention         224.326782           223.0           3816    26.565103
# New Customers           49.957709            46.0           3807    25.845727
# Potential Loyalists     94.671215            97.0          15244    51.557566
# Promising              140.527727           139.0           3805    23.794844
#
#                      Frequency_mean  Frequency_median  Frequency_count  \
# Segment
# About to Sleep             1.000000               1.0             7498
# At Risk                    1.000000               1.0            15220
# Can't Loose                1.148876               1.0             7429
# Champions                  1.098857               1.0             7698
# Hibernating                1.000000               1.0            15244
# Loyal Customers            1.088622               1.0            15222
# Need Attention             1.000000               1.0             3816
# New Customers              1.000000               1.0             3807
# Potential Loyalists        1.000000               1.0            15244
# Promising                  1.000000               1.0             3805
#
#                      Frequency_std  Monetary_mean  Monetary_median  \
# Segment
# About to Sleep            0.000000     189.727893          108.270
# At Risk                   0.000000     204.483072          107.780
# Can't Loose               0.389576     231.164072          120.180
# Champions                 0.394810     228.152181          120.130
# Hibernating               0.000000     214.282203          107.790
# Loyal Customers           0.328592     227.130378          117.745
# Need Attention            0.000000     183.637285          106.815
# New Customers             0.000000     203.995960          115.720
# Potential Loyalists       0.000000     204.416115          113.165
# Promising                 0.000000     212.382063          111.620
#
#                      Monetary_count  Monetary_std
# Segment
# About to Sleep                 7498    392.786561
# At Risk                       15220    564.295942
# Can't Loose                    7429    476.559589
# Champions                      7698    616.523477
# Hibernating                   15244   1040.432000
# Loyal Customers               15222    661.144163
# Need Attention                 3816    287.948007
# New Customers                  3807    390.300150
# Potential Loyalists           15244    458.231167
# Promising                      3805    506.352684

# %%
rfm_count = rfm.groupby('Segment')['customer_unique_id'].nunique().reset_index(name='count')
rfm_count['percentage'] = (rfm_count['count'] / rfm_count['count'].sum()) * 100
Segment = rfm_count.sort_values(by='count', ascending=False)
Segment
# Out:
#                Segment  count  percentage
# 4          Hibernating  15244   16.049188
# 8  Potential Loyalists  15244   16.049188
# 5      Loyal Customers  15222   16.026026
# 1              At Risk  15220   16.023920
# 3            Champions   7698    8.104608
# 0       About to Sleep   7498    7.894044
# 2          Can't Loose   7429    7.821400
# 6       Need Attention   3816    4.017561
# 7        New Customers   3807    4.008086
# 9            Promising   3805    4.005980

# %% [markdown]
# Hibernating, Potential Loyalists, Loyal Customers, and At Risk have the most perentage portion which 16% in each category. Meanwhile, Need Attention, New Customers, and Promising have the least percentage portion which 4% in each category.
